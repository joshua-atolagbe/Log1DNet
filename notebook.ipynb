# %% [markdown]
# <a href="https://colab.research.google.com/github/joshua-atolagbe/Log1DNet/blob/master/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/joshua-atolagbe/Log1DNet.git
# Out:
# Cloning into 'Log1DNet'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 34 (delta 5), reused 30 (delta 4), pack-reused 0
# Receiving objects: 100% (34/34), 12.99 KiB | 12.99 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# # Step 0: Packages

# %%
# !pip install -r /content/Log1DNet/requirements.txt
# Out:
# Collecting pytorch.ignite==0.5.0.post2 (from -r /content/Log1DNet/requirements.txt (line 1))
#   Downloading pytorch_ignite-0.5.0.post2-py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas==2.0.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/Log1DNet/requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: numpy==1.25.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/Log1DNet/requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/Log1DNet/requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: seaborn==0.13.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/Log1DNet/requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/Log1DNet/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: torch==2.3.0+cu121 in /usr/local/lib/python3.10/dist-packages (from -r /content/Log1DNet/requirements.txt (line 7)) (2.3.0+cu121)
# Collecting lasio==0.31 (from -r /content/Log1DNet/requirements.txt (line 8))
#   Downloading lasio-0.31-py2.py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from pytorch.ignite==0.5.0.post2->-r /content/Log1DNet/requirements.txt (line 1)) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->-r /content/Log1DNet/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->-r /content/Log1DNet/requirements.txt (line 2)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->-r /content/Log1DNet/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->-r /content/Log1DNet/requirements.txt (line 4)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->-r /content/Log1DNet/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->-r /content/Log1DNet/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/Log1DNet/requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/Log1DNet/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/Log1DNet/requirements.txt (line 6)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/Log1DNet/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/Log1DNet/requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r /content/Log1DNet/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7))
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 48.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3->-r /content/Log1DNet/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0+cu121->-r /content/Log1DNet/requirements.txt (line 7)) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lasio, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch.ignite
# Successfully installed lasio-0.31 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pytorch.ignite-0.5.0.post2

# %%
import os
import sys
import lasio
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
from numpy import Inf, sqrt
from tqdm.auto import tqdm

import sklearn
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split

import torch

sys.path.append('/content/Log1DNet')
from Log1DNet.src import *
from train import main
# from plots import *
# from loader import *
# from dataloader import dloader
# from metrics import *

from warnings import filterwarnings
filterwarnings('ignore')

# %matplotlib inline
# %config BackendInline.figure_format = 'retina'
pd.options.display.max_columns = 23

# %% [markdown]
# # Step 1: Data Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def plot_well_loc(files):

    '''
    returns the location of the well if available in the original LAS file
    args::
        files: LAS file_path takes in the original LAS file as argument

    '''
    well_name = list()
    latitude = list()
    longitude = list()
    max_depth = list()


    for file in files:
        well_name.append(f'{str(file[2:-4])}')
        well_data = lasio.read(os.path.join("/content/drive/My Drive/Sonic Log Prediction/data/", file))
        longitude.append(well_data.well.LONG.value)
        latitude.append(well_data.well.LATI.value)
        max_depth.append(well_data.well.STOP.value)

    well_df = pd.DataFrame({'WELL_NAME':well_name,'LAT':latitude,'LONG':longitude,'DEPTH':max_depth})

    plt.figure(figsize=(10,10))
    plt.title('WELLS LOCATION')
    sns.scatterplot(x ='LAT', y = 'LONG', data = well_df,
                    size= [60, 40, 60], sizes = (100,600), style='WELL_NAME')

    for well in range(0,well_df.shape[0]):
         plt.text(well_df.LAT[well], well_df.LONG[well], files[well][:-4],
                  horizontalalignment='left', size='medium', color='black')

files = ['15_9-F-1A.LAS', '15_9-F-1B.LAS', '15_9-F-11A.LAS',]

plot_well_loc(files)

# %%
# get all paths and alphabetically ordered
# paths = sorted(glob.glob(os.path.join("./", "*.LAS")))
paths = ['15_9-F-11A.LAS', '15_9-F-11T2.LAS', '15_9-F-1A.LAS', '15_9-F-1B.LAS',
         '15_9-F-4.LAS']

well_df = [0] * 5

for i in range(len(paths)):
    # read with lasio and convert to dataframe
    df = (lasio.read(os.path.join("/content/drive/My Drive/Sonic Log Prediction/data/", paths[i]))).df()

    well_df[i] = df.reset_index()

well1, well2, well3, well4, well5 = well_df

# %%
well1 = process_train(well1, col, name='15_9-F-11A')
well2 = process_test(well2, col, name='15_9-F-11T2') #validation
well3 = process_train(well3, col, name='15_9-F-1A')
well4 = process_train(well4, col, name='15_9-F-1B')
well5 = process_test(well5, col, name='15_9-F-4') #validation

# %%
train = pd.concat((well1, well3, well4), axis='index').reset_index(drop=True)
test = pd.concat((well2, well5), axis='index').reset_index(drop=True)

# %% [markdown]
# #Step 2: Visualizations

# %%
corr = Correlation(train.select_dtypes('float64'))
v = corr.corr(method='chatterjee')
corr.plot_heatmap(' ', cmap='Spectral')

# %%
corr = Correlation(train.select_dtypes('float64'))
v = corr.corr(method='pearsonr')
corr.plot_heatmap(' ', cmap='Spectral')

# %% [markdown]
# # Step 4: Data Tranformation

# %%
#combine train and test for easy transformation
wells = pd.concat((train, test), axis='index').reset_index(drop=True)

wells['GR'] = np.where(wells['GR'] <= 200., wells['GR'], 200.)
wells['RT'] = np.where(wells['RT'] <= 2000., wells['RT'], 2000.)

wells['RT'] = np.log10(wells['RT'])

# %%
#split back into train and test
train_ = wells[:train.shape[0]]
test_ = wells[train.shape[0]:]

features = ['GR', 'RT', 'RHOB', 'NPHI'] # only feature column names
target = ['DTC', 'DTS'] # only target column names
feature_target = ['GR', 'RT', 'RHOB', 'NPHI', 'DEPTH', 'WELL', 'DTC', 'DTS']

#scaler
scaler = PowerTransformer(method='yeo-johnson')
ct = ColumnTransformer([('transform', scaler, features)], remainder='passthrough').fit(train_)

#transform train and test set
t_new_wells = ct.transform(train_)
tt_new_wells = ct.transform(test_)

t_wells_norm = pd.DataFrame(t_new_wells, columns=feature_target)
tt_wells_norm = pd.DataFrame(tt_new_wells, columns=feature_target)


#convert into correct type
x1 = t_wells_norm[features].astype(float)
y1 = t_wells_norm['WELL'].astype(str)
z1 = t_wells_norm['DEPTH'].astype(float)

x2 = tt_wells_norm[features].astype(float)
y2 = tt_wells_norm['WELL'].astype(str)
z2 = tt_wells_norm['DEPTH'].astype(float)

#joining data together
t_wells_norm = pd.concat([z1, y1, x1], axis=1)
t_wells_norm['DTC'] = train_.DTC
t_wells_norm['DTS'] = train_.DTS

tt_wells_norm = pd.concat([z2, y2, x2], axis=1)
tt_wells_norm['DTC'] = test_.DTC
tt_wells_norm['DTS'] = test_.DTS

# %% [markdown]
# # Step 5: Data split

# %%
#split into train, val and test set
train_x_ = t_wells_norm[t_wells_norm.columns[2:6]]
train_y_ = t_wells_norm[['DTC', 'DTS']]


test_x = tt_wells_norm[tt_wells_norm.columns[2:6]]
test_y = tt_wells_norm[['DTC', 'DTS']]

# #train and validation split
train_x, val_x, train_y, val_y = train_test_split(train_x_, train_y_, shuffle=True,
                                                  test_size=0.3, random_state=2024)

# %%
#propocessed blind test wells
test_well2_x = test_x[:well2.shape[0]]
test_well2_y = test_y[:well2.shape[0]]

test_well5_x = test_x[well2.shape[0]:]
test_well5_y = test_y[well2.shape[0]:]

# %%
#propocessed training wells
train_well1_x = train_x_[:well1.shape[0]]
train_well1_y = train_y_[:well1.shape[0]]

train_well3_x = train_x_[well1.shape[0]:(well1.shape[0]+well3.shape[0])]
train_well3_y = train_y_[well1.shape[0]:(well1.shape[0]+well3.shape[0])]

train_well4_x = train_x_[(well1.shape[0]+well3.shape[0]):]
train_well4_y = train_y_[(well1.shape[0]+well3.shape[0]):]

# %% [markdown]
# # Step 7: Model training

# %%
EPOCHS = 300
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
BATCH_SIZE = 256

# %%
trainloader = dloader(train_x, train_y, bs=256)
valloader = dloader(val_x, val_y, bs=256)

# %%
random_seed = 2024
torch.manual_seed(random_seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

model = Log1DNetv3(batch_size=256)

print(model.to(device))

train_dtc_loss, train_dtc_score, train_dts_loss, train_dts_score,\
    val_dtc_loss, val_dtc_score, val_dts_loss, val_dts_score = main(model, trainloader,
                                                                    valloader, epochs=EPOCHS)
# Out:
# Log1DNetv3(
#   (conv1): Sequential(
#     (0): Conv1d(4, 256, kernel_size=(1,), stride=(1,))
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): AvgPool1d(kernel_size=(1,), stride=(1,), padding=(0,))
#   )
#   (conv2): Sequential(
#     (0): Conv1d(256, 512, kernel_size=(1,), stride=(1,))
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): AvgPool1d(kernel_size=(1,), stride=(1,), padding=(0,))
#   )
#   (conv3): Sequential(
#     (0): Conv1d(512, 1024, kernel_size=(1,), stride=(1,))
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv4): Sequential(
#     (0): Conv1d(1024, 256, kernel_size=(1,), stride=(1,))
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (layer): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#   )
#   (output): Sequential(
#     (0): Linear(in_features=256, out_features=2, bias=True)
#   )
# )
#   0%|          | 0/300 [00:00<?, ?it/s]
# Model Saved
# Epoch 1 Train: DTC Loss=43.6431 | DTC Score=-23.8882 | DTS Loss=105.5390 | DTS Score=-13.5853
# Epoch 1 Val: DTC Loss=8.6445 | DTC Score=0.5404 | DTS Loss=29.2960 | DTS Score=0.2816
#
# Model Saved
# Epoch 2 Train: DTC Loss=6.8362 | DTC Score=0.6896 | DTS Loss=18.7275 | DTS Score=0.6408
# Epoch 2 Val: DTC Loss=5.4766 | DTC Score=0.8324 | DTS Loss=17.8802 | DTS Score=0.7260
#
# Model Saved
# Epoch 3 Train: DTC Loss=5.7546 | DTC Score=0.7996 | DTS Loss=16.6806 | DTS Score=0.7652
# Epoch 3 Val: DTC Loss=5.5036 | DTC Score=0.8164 | DTS Loss=16.3743 | DTS Score=0.7718
#
# Epoch 4 Train: DTC Loss=5.2381 | DTC Score=0.8319 | DTS Loss=15.9193 | DTS Score=0.7822
# Epoch 4 Val: DTC Loss=5.4414 | DTC Score=0.8020 | DTS Loss=16.5932 | DTS Score=0.7690
#
# Model Saved
# Epoch 5 Train: DTC Loss=4.5933 | DTC Score=0.8707 | DTS Loss=15.5275 | DTS Score=0.7910
# Epoch 5 Val: DTC Loss=4.8797 | DTC Score=0.8591 | DTS Loss=15.8516 | DTS Score=0.7926
#
# Model Saved
# Epoch 6 Train: DTC Loss=4.5155 | DTC Score=0.8643 | DTS Loss=15.3727 | DTS Score=0.7941
# Epoch 6 Val: DTC Loss=4.5189 | DTC Score=0.8761 | DTS Loss=15.5285 | DTS Score=0.8031
#
# Model Saved
# Epoch 7 Train: DTC Loss=4.1939 | DTC Score=0.8907 | DTS Loss=15.0071 | DTS Score=0.8080
# Epoch 7 Val: DTC Loss=4.2014 | DTC Score=0.8971 | DTS Loss=15.1004 | DTS Score=0.8254
#
# Model Saved
# Epoch 8 Train: DTC Loss=4.1154 | DTC Score=0.9001 | DTS Loss=14.8937 | DTS Score=0.8136
# Epoch 8 Val: DTC Loss=3.9020 | DTC Score=0.9162 | DTS Loss=15.0973 | DTS Score=0.8118
#
# Epoch 9 Train: DTC Loss=4.1025 | DTC Score=0.9099 | DTS Loss=14.6831 | DTS Score=0.8290
# Epoch 9 Val: DTC Loss=4.4106 | DTC Score=0.8896 | DTS Loss=14.7933 | DTS Score=0.8281
#
# Epoch 10 Train: DTC Loss=4.1791 | DTC Score=0.8966 | DTS Loss=14.6197 | DTS Score=0.8303
# Epoch 10 Val: DTC Loss=4.4697 | DTC Score=0.8845 | DTS Loss=15.6457 | DTS Score=0.7979
#
# Epoch 11 Train: DTC Loss=3.9018 | DTC Score=0.9136 | DTS Loss=14.4009 | DTS Score=0.8212
# Epoch 11 Val: DTC Loss=4.5081 | DTC Score=0.8660 | DTS Loss=15.3116 | DTS Score=0.7953
#
# Epoch 12 Train: DTC Loss=4.2106 | DTC Score=0.8931 | DTS Loss=14.6906 | DTS Score=0.8191
# Epoch 12 Val: DTC Loss=4.3022 | DTC Score=0.8875 | DTS Loss=15.0806 | DTS Score=0.8096
#
# Model Saved
# Epoch 13 Train: DTC Loss=4.1845 | DTC Score=0.9044 | DTS Loss=14.5494 | DTS Score=0.8256
# Epoch 13 Val: DTC Loss=4.1887 | DTC Score=0.8964 | DTS Loss=14.7967 | DTS Score=0.8300
#
# Model Saved
# Epoch 14 Train: DTC Loss=4.0595 | DTC Score=0.9001 | DTS Loss=14.3845 | DTS Score=0.8243
# Epoch 14 Val: DTC Loss=4.0439 | DTC Score=0.9100 | DTS Loss=14.5241 | DTS Score=0.8285
#
# Epoch 15 Train: DTC Loss=4.0082 | DTC Score=0.9117 | DTS Loss=14.1415 | DTS Score=0.8332
# Epoch 15 Val: DTC Loss=4.8946 | DTC Score=0.8550 | DTS Loss=15.0835 | DTS Score=0.8247
#
# Model Saved
# Epoch 16 Train: DTC Loss=3.8532 | DTC Score=0.9150 | DTS Loss=14.2771 | DTS Score=0.8256
# Epoch 16 Val: DTC Loss=3.6447 | DTC Score=0.9173 | DTS Loss=14.6377 | DTS Score=0.8225
#
# Epoch 17 Train: DTC Loss=3.8897 | DTC Score=0.9190 | DTS Loss=14.1349 | DTS Score=0.8468
# Epoch 17 Val: DTC Loss=3.9184 | DTC Score=0.9071 | DTS Loss=14.5551 | DTS Score=0.8184
#
# Epoch 18 Train: DTC Loss=3.8767 | DTC Score=0.9150 | DTS Loss=14.1002 | DTS Score=0.8436
# Epoch 18 Val: DTC Loss=3.8946 | DTC Score=0.9101 | DTS Loss=14.4335 | DTS Score=0.8318
#
# Epoch 19 Train: DTC Loss=3.7704 | DTC Score=0.9180 | DTS Loss=13.9284 | DTS Score=0.8353
# Epoch 19 Val: DTC Loss=3.7733 | DTC Score=0.9235 | DTS Loss=14.6868 | DTS Score=0.8082
#
# Model Saved
# Epoch 20 Train: DTC Loss=4.1365 | DTC Score=0.8986 | DTS Loss=14.5166 | DTS Score=0.8096
# Epoch 20 Val: DTC Loss=3.6857 | DTC Score=0.9214 | DTS Loss=14.2675 | DTS Score=0.8348
#
# Epoch 21 Train: DTC Loss=3.8360 | DTC Score=0.9063 | DTS Loss=14.0148 | DTS Score=0.8413
# Epoch 21 Val: DTC Loss=3.7668 | DTC Score=0.9143 | DTS Loss=14.5359 | DTS Score=0.8323
#
# Epoch 22 Train: DTC Loss=3.8746 | DTC Score=0.9202 | DTS Loss=13.9918 | DTS Score=0.8402
# Epoch 22 Val: DTC Loss=3.7687 | DTC Score=0.9123 | DTS Loss=14.6142 | DTS Score=0.8201
#
# Epoch 23 Train: DTC Loss=3.7072 | DTC Score=0.9257 | DTS Loss=13.7334 | DTS Score=0.8463
# Epoch 23 Val: DTC Loss=3.7641 | DTC Score=0.9208 | DTS Loss=14.1921 | DTS Score=0.8349
#
# Epoch 24 Train: DTC Loss=3.7798 | DTC Score=0.9171 | DTS Loss=13.6995 | DTS Score=0.8519
# Epoch 24 Val: DTC Loss=3.7533 | DTC Score=0.9204 | DTS Loss=14.2253 | DTS Score=0.8377
#
# Epoch 25 Train: DTC Loss=3.7649 | DTC Score=0.9227 | DTS Loss=13.5921 | DTS Score=0.8471
# Epoch 25 Val: DTC Loss=3.7207 | DTC Score=0.9196 | DTS Loss=14.7127 | DTS Score=0.8277
#
# Epoch 26 Train: DTC Loss=3.8154 | DTC Score=0.9146 | DTS Loss=13.7680 | DTS Score=0.8292
# Epoch 26 Val: DTC Loss=3.9970 | DTC Score=0.8954 | DTS Loss=14.3682 | DTS Score=0.8189
#
# Epoch 27 Train: DTC Loss=3.7826 | DTC Score=0.9084 | DTS Loss=13.6543 | DTS Score=0.8340
# Epoch 27 Val: DTC Loss=3.8676 | DTC Score=0.9188 | DTS Loss=14.3003 | DTS Score=0.8413
#
# Epoch 28 Train: DTC Loss=3.7367 | DTC Score=0.9167 | DTS Loss=13.6630 | DTS Score=0.8459
# Epoch 28 Val: DTC Loss=3.6631 | DTC Score=0.9242 | DTS Loss=14.2996 | DTS Score=0.8445
#
# Epoch 29 Train: DTC Loss=3.8505 | DTC Score=0.9199 | DTS Loss=13.8089 | DTS Score=0.8508
# Epoch 29 Val: DTC Loss=4.2633 | DTC Score=0.8896 | DTS Loss=14.5209 | DTS Score=0.8419
#
# Epoch 30 Train: DTC Loss=3.6425 | DTC Score=0.9231 | DTS Loss=13.8776 | DTS Score=0.8378
# Epoch 30 Val: DTC Loss=3.8932 | DTC Score=0.9115 | DTS Loss=14.3975 | DTS Score=0.8328
#
# Epoch 31 Train: DTC Loss=3.7804 | DTC Score=0.9212 | DTS Loss=13.7537 | DTS Score=0.8477
# Epoch 31 Val: DTC Loss=3.7178 | DTC Score=0.9223 | DTS Loss=14.3104 | DTS Score=0.8356
#
# Model Saved
# Epoch 32 Train: DTC Loss=3.7357 | DTC Score=0.9211 | DTS Loss=13.6842 | DTS Score=0.8489
# Epoch 32 Val: DTC Loss=3.7974 | DTC Score=0.9165 | DTS Loss=13.8466 | DTS Score=0.8385
#
# Epoch 33 Train: DTC Loss=3.7571 | DTC Score=0.9211 | DTS Loss=13.7042 | DTS Score=0.8417
# Epoch 33 Val: DTC Loss=3.8419 | DTC Score=0.9126 | DTS Loss=14.1285 | DTS Score=0.8417
#
# Epoch 34 Train: DTC Loss=3.9279 | DTC Score=0.9230 | DTS Loss=13.9424 | DTS Score=0.8436
# Epoch 34 Val: DTC Loss=3.9905 | DTC Score=0.9051 | DTS Loss=14.1424 | DTS Score=0.8447
#
# Epoch 35 Train: DTC Loss=3.7197 | DTC Score=0.9216 | DTS Loss=13.7215 | DTS Score=0.8437
# Epoch 35 Val: DTC Loss=4.4205 | DTC Score=0.8860 | DTS Loss=14.4564 | DTS Score=0.8275
#
# Epoch 36 Train: DTC Loss=3.7508 | DTC Score=0.9110 | DTS Loss=13.5923 | DTS Score=0.8525
# Epoch 36 Val: DTC Loss=3.7915 | DTC Score=0.9132 | DTS Loss=14.5363 | DTS Score=0.8318
#
# Epoch 37 Train: DTC Loss=3.7022 | DTC Score=0.9167 | DTS Loss=13.4719 | DTS Score=0.8525
# Epoch 37 Val: DTC Loss=3.8607 | DTC Score=0.9070 | DTS Loss=14.6577 | DTS Score=0.8162
#
# Epoch 38 Train: DTC Loss=3.7741 | DTC Score=0.9163 | DTS Loss=13.6902 | DTS Score=0.8430
# Epoch 38 Val: DTC Loss=3.7695 | DTC Score=0.9136 | DTS Loss=14.5844 | DTS Score=0.8183
#
# Epoch 39 Train: DTC Loss=3.8078 | DTC Score=0.9151 | DTS Loss=13.5531 | DTS Score=0.8492
# Epoch 39 Val: DTC Loss=3.9673 | DTC Score=0.9127 | DTS Loss=14.6627 | DTS Score=0.8274
#
# Epoch 40 Train: DTC Loss=3.8440 | DTC Score=0.9175 | DTS Loss=13.5690 | DTS Score=0.8542
# Epoch 40 Val: DTC Loss=4.2333 | DTC Score=0.8876 | DTS Loss=14.0161 | DTS Score=0.8516
#
# Epoch 41 Train: DTC Loss=3.6671 | DTC Score=0.9200 | DTS Loss=13.4596 | DTS Score=0.8518
# Epoch 41 Val: DTC Loss=3.6683 | DTC Score=0.9218 | DTS Loss=14.0083 | DTS Score=0.8276
#
# Model Saved
# Epoch 42 Train: DTC Loss=3.6011 | DTC Score=0.9224 | DTS Loss=13.3331 | DTS Score=0.8518
# Epoch 42 Val: DTC Loss=3.5441 | DTC Score=0.9296 | DTS Loss=13.7863 | DTS Score=0.8381
#
# Epoch 43 Train: DTC Loss=3.7495 | DTC Score=0.9231 | DTS Loss=13.4839 | DTS Score=0.8465
# Epoch 43 Val: DTC Loss=3.5384 | DTC Score=0.9242 | DTS Loss=14.2882 | DTS Score=0.8155
#
# Epoch 44 Train: DTC Loss=3.7750 | DTC Score=0.9217 | DTS Loss=13.3730 | DTS Score=0.8439
# Epoch 44 Val: DTC Loss=3.5660 | DTC Score=0.9254 | DTS Loss=13.9562 | DTS Score=0.8372
#
# Epoch 45 Train: DTC Loss=3.6974 | DTC Score=0.9208 | DTS Loss=13.5177 | DTS Score=0.8551
# Epoch 45 Val: DTC Loss=4.3540 | DTC Score=0.8881 | DTS Loss=14.1437 | DTS Score=0.8282
#
# Model Saved
# Epoch 46 Train: DTC Loss=3.6741 | DTC Score=0.9165 | DTS Loss=13.2944 | DTS Score=0.8531
# Epoch 46 Val: DTC Loss=3.4162 | DTC Score=0.9328 | DTS Loss=13.7534 | DTS Score=0.8381
#
# Epoch 47 Train: DTC Loss=3.6729 | DTC Score=0.9291 | DTS Loss=13.3856 | DTS Score=0.8487
# Epoch 47 Val: DTC Loss=4.1779 | DTC Score=0.9015 | DTS Loss=14.1223 | DTS Score=0.8383
#
# Epoch 48 Train: DTC Loss=3.5305 | DTC Score=0.9252 | DTS Loss=13.1151 | DTS Score=0.8543
# Epoch 48 Val: DTC Loss=3.5484 | DTC Score=0.9225 | DTS Loss=13.8134 | DTS Score=0.8568
#
# Epoch 49 Train: DTC Loss=3.7678 | DTC Score=0.9206 | DTS Loss=13.3840 | DTS Score=0.8548
# Epoch 49 Val: DTC Loss=3.7891 | DTC Score=0.9225 | DTS Loss=14.1101 | DTS Score=0.8469
#
# Epoch 50 Train: DTC Loss=3.6028 | DTC Score=0.9223 | DTS Loss=13.3132 | DTS Score=0.8533
# Epoch 50 Val: DTC Loss=3.7701 | DTC Score=0.9139 | DTS Loss=14.2587 | DTS Score=0.8403
#
# Epoch 51 Train: DTC Loss=3.6064 | DTC Score=0.9235 | DTS Loss=13.2971 | DTS Score=0.8518
# Epoch 51 Val: DTC Loss=3.6549 | DTC Score=0.9273 | DTS Loss=13.8876 | DTS Score=0.8433
#
# Epoch 52 Train: DTC Loss=3.6105 | DTC Score=0.9212 | DTS Loss=13.2115 | DTS Score=0.8579
# Epoch 52 Val: DTC Loss=3.7111 | DTC Score=0.9220 | DTS Loss=14.4796 | DTS Score=0.8286
#
# Epoch 53 Train: DTC Loss=3.6937 | DTC Score=0.9248 | DTS Loss=13.2598 | DTS Score=0.8611
# Epoch 53 Val: DTC Loss=3.7594 | DTC Score=0.9216 | DTS Loss=14.2349 | DTS Score=0.8260
#
# Epoch 54 Train: DTC Loss=3.5369 | DTC Score=0.9301 | DTS Loss=13.1643 | DTS Score=0.8681
# Epoch 54 Val: DTC Loss=3.9732 | DTC Score=0.9037 | DTS Loss=14.1564 | DTS Score=0.8244
#
# Epoch 55 Train: DTC Loss=3.8175 | DTC Score=0.9088 | DTS Loss=13.3050 | DTS Score=0.8459
# Epoch 55 Val: DTC Loss=3.7020 | DTC Score=0.9248 | DTS Loss=13.9799 | DTS Score=0.8475
#
# Epoch 56 Train: DTC Loss=3.6071 | DTC Score=0.9272 | DTS Loss=13.2865 | DTS Score=0.8578
# Epoch 56 Val: DTC Loss=3.8402 | DTC Score=0.9094 | DTS Loss=14.4083 | DTS Score=0.8343
#
# Epoch 57 Train: DTC Loss=3.5651 | DTC Score=0.9266 | DTS Loss=13.1449 | DTS Score=0.8539
# Epoch 57 Val: DTC Loss=3.5875 | DTC Score=0.9229 | DTS Loss=13.9931 | DTS Score=0.8508
#
# Epoch 58 Train: DTC Loss=3.7361 | DTC Score=0.9201 | DTS Loss=13.2080 | DTS Score=0.8564
# Epoch 58 Val: DTC Loss=4.0078 | DTC Score=0.9047 | DTS Loss=14.0414 | DTS Score=0.8371
#
# Model Saved
# Epoch 59 Train: DTC Loss=3.8172 | DTC Score=0.9168 | DTS Loss=13.2781 | DTS Score=0.8523
# Epoch 59 Val: DTC Loss=3.5024 | DTC Score=0.9293 | DTS Loss=13.4892 | DTS Score=0.8485
#
# Epoch 60 Train: DTC Loss=3.5755 | DTC Score=0.9287 | DTS Loss=13.0803 | DTS Score=0.8478
# Epoch 60 Val: DTC Loss=3.7345 | DTC Score=0.9191 | DTS Loss=13.8361 | DTS Score=0.8388
#
# Epoch 61 Train: DTC Loss=3.7176 | DTC Score=0.9162 | DTS Loss=13.0217 | DTS Score=0.8540
# Epoch 61 Val: DTC Loss=3.7362 | DTC Score=0.9194 | DTS Loss=13.7858 | DTS Score=0.8405
#
# Epoch 62 Train: DTC Loss=3.6218 | DTC Score=0.9250 | DTS Loss=13.0693 | DTS Score=0.8647
# Epoch 62 Val: DTC Loss=3.6685 | DTC Score=0.9204 | DTS Loss=13.8832 | DTS Score=0.8217
#
# Epoch 63 Train: DTC Loss=3.6262 | DTC Score=0.9269 | DTS Loss=13.1004 | DTS Score=0.8625
# Epoch 63 Val: DTC Loss=3.6377 | DTC Score=0.9232 | DTS Loss=14.0502 | DTS Score=0.8291
#
# Epoch 64 Train: DTC Loss=3.5385 | DTC Score=0.9307 | DTS Loss=13.0702 | DTS Score=0.8535
# Epoch 64 Val: DTC Loss=3.7197 | DTC Score=0.9194 | DTS Loss=13.6599 | DTS Score=0.8478
#
# Epoch 65 Train: DTC Loss=3.5685 | DTC Score=0.9262 | DTS Loss=12.8642 | DTS Score=0.8575
# Epoch 65 Val: DTC Loss=3.6846 | DTC Score=0.9252 | DTS Loss=13.7765 | DTS Score=0.8327
#
# Epoch 66 Train: DTC Loss=3.5387 | DTC Score=0.9267 | DTS Loss=12.9168 | DTS Score=0.8582
# Epoch 66 Val: DTC Loss=3.5760 | DTC Score=0.9279 | DTS Loss=13.4632 | DTS Score=0.8567
#
# Model Saved
# Epoch 67 Train: DTC Loss=3.5772 | DTC Score=0.9272 | DTS Loss=12.9295 | DTS Score=0.8610
# Epoch 67 Val: DTC Loss=3.4278 | DTC Score=0.9300 | DTS Loss=13.5124 | DTS Score=0.8479
#
# Epoch 68 Train: DTC Loss=3.5481 | DTC Score=0.9319 | DTS Loss=12.9130 | DTS Score=0.8713
# Epoch 68 Val: DTC Loss=3.5319 | DTC Score=0.9300 | DTS Loss=13.5029 | DTS Score=0.8496
#
# Epoch 69 Train: DTC Loss=3.5344 | DTC Score=0.9271 | DTS Loss=12.9354 | DTS Score=0.8622
# Epoch 69 Val: DTC Loss=3.4347 | DTC Score=0.9337 | DTS Loss=13.6329 | DTS Score=0.8642
#
# Epoch 70 Train: DTC Loss=3.4732 | DTC Score=0.9324 | DTS Loss=12.8488 | DTS Score=0.8628
# Epoch 70 Val: DTC Loss=3.5103 | DTC Score=0.9286 | DTS Loss=14.0419 | DTS Score=0.8440
#
# Epoch 71 Train: DTC Loss=3.4704 | DTC Score=0.9320 | DTS Loss=12.6901 | DTS Score=0.8630
# Epoch 71 Val: DTC Loss=3.5076 | DTC Score=0.9274 | DTS Loss=13.7218 | DTS Score=0.8518
#
# Epoch 72 Train: DTC Loss=3.5739 | DTC Score=0.9290 | DTS Loss=12.9137 | DTS Score=0.8615
# Epoch 72 Val: DTC Loss=3.9127 | DTC Score=0.9077 | DTS Loss=14.0987 | DTS Score=0.8203
#
# Epoch 73 Train: DTC Loss=3.4905 | DTC Score=0.9296 | DTS Loss=12.8760 | DTS Score=0.8673
# Epoch 73 Val: DTC Loss=3.7471 | DTC Score=0.9143 | DTS Loss=13.7770 | DTS Score=0.8473
#
# Epoch 74 Train: DTC Loss=3.5700 | DTC Score=0.9272 | DTS Loss=12.7875 | DTS Score=0.8706
# Epoch 74 Val: DTC Loss=3.5044 | DTC Score=0.9259 | DTS Loss=14.2369 | DTS Score=0.8285
#
# Epoch 75 Train: DTC Loss=3.8454 | DTC Score=0.9162 | DTS Loss=13.4203 | DTS Score=0.8521
# Epoch 75 Val: DTC Loss=3.5526 | DTC Score=0.9249 | DTS Loss=13.7572 | DTS Score=0.8496
#
# Epoch 76 Train: DTC Loss=3.5009 | DTC Score=0.9261 | DTS Loss=12.8235 | DTS Score=0.8620
# Epoch 76 Val: DTC Loss=3.6620 | DTC Score=0.9221 | DTS Loss=13.5355 | DTS Score=0.8502
#
# Epoch 77 Train: DTC Loss=3.4923 | DTC Score=0.9292 | DTS Loss=12.9688 | DTS Score=0.8616
# Epoch 77 Val: DTC Loss=3.6705 | DTC Score=0.9205 | DTS Loss=13.7108 | DTS Score=0.8405
#
# Epoch 78 Train: DTC Loss=3.5151 | DTC Score=0.9271 | DTS Loss=12.8351 | DTS Score=0.8627
# Epoch 78 Val: DTC Loss=3.7122 | DTC Score=0.9182 | DTS Loss=13.9273 | DTS Score=0.8501
#
# Epoch 79 Train: DTC Loss=3.5812 | DTC Score=0.9263 | DTS Loss=12.7518 | DTS Score=0.8660
# Epoch 79 Val: DTC Loss=3.7982 | DTC Score=0.9132 | DTS Loss=13.7534 | DTS Score=0.8566
#
# Epoch 80 Train: DTC Loss=3.4597 | DTC Score=0.9313 | DTS Loss=12.7216 | DTS Score=0.8691
# Epoch 80 Val: DTC Loss=3.6695 | DTC Score=0.9144 | DTS Loss=13.4716 | DTS Score=0.8548
#
# Epoch 81 Train: DTC Loss=3.4962 | DTC Score=0.9287 | DTS Loss=12.6500 | DTS Score=0.8657
# Epoch 81 Val: DTC Loss=3.5764 | DTC Score=0.9221 | DTS Loss=13.6206 | DTS Score=0.8349
#
# Epoch 82 Train: DTC Loss=3.4988 | DTC Score=0.9318 | DTS Loss=12.7103 | DTS Score=0.8762
# Epoch 82 Val: DTC Loss=3.5175 | DTC Score=0.9275 | DTS Loss=13.6374 | DTS Score=0.8597
#
# Epoch 83 Train: DTC Loss=3.4913 | DTC Score=0.9252 | DTS Loss=12.8529 | DTS Score=0.8543
# Epoch 83 Val: DTC Loss=3.5357 | DTC Score=0.9273 | DTS Loss=13.6736 | DTS Score=0.8497
#
# Epoch 84 Train: DTC Loss=3.5096 | DTC Score=0.9303 | DTS Loss=12.8452 | DTS Score=0.8618
# Epoch 84 Val: DTC Loss=3.6144 | DTC Score=0.9254 | DTS Loss=13.6280 | DTS Score=0.8446
#
# Epoch 85 Train: DTC Loss=3.4423 | DTC Score=0.9298 | DTS Loss=12.5093 | DTS Score=0.8756
# Epoch 85 Val: DTC Loss=3.5629 | DTC Score=0.9315 | DTS Loss=13.5407 | DTS Score=0.8483
#
# Model Saved
# Epoch 86 Train: DTC Loss=3.4954 | DTC Score=0.9319 | DTS Loss=12.7489 | DTS Score=0.8716
# Epoch 86 Val: DTC Loss=3.4559 | DTC Score=0.9321 | DTS Loss=13.3885 | DTS Score=0.8518
#
# Epoch 87 Train: DTC Loss=3.5292 | DTC Score=0.9302 | DTS Loss=12.7024 | DTS Score=0.8699
# Epoch 87 Val: DTC Loss=3.6754 | DTC Score=0.9199 | DTS Loss=13.6195 | DTS Score=0.8382
#
# Epoch 88 Train: DTC Loss=3.5298 | DTC Score=0.9280 | DTS Loss=12.8228 | DTS Score=0.8660
# Epoch 88 Val: DTC Loss=3.7351 | DTC Score=0.9160 | DTS Loss=14.0266 | DTS Score=0.8364
#
# Epoch 89 Train: DTC Loss=3.4890 | DTC Score=0.9280 | DTS Loss=12.6265 | DTS Score=0.8636
# Epoch 89 Val: DTC Loss=3.6011 | DTC Score=0.9233 | DTS Loss=13.7714 | DTS Score=0.8303
#
# Epoch 90 Train: DTC Loss=3.4082 | DTC Score=0.9332 | DTS Loss=12.5075 | DTS Score=0.8772
# Epoch 90 Val: DTC Loss=3.5974 | DTC Score=0.9227 | DTS Loss=14.0585 | DTS Score=0.8277
#
# Epoch 91 Train: DTC Loss=3.5861 | DTC Score=0.9302 | DTS Loss=12.8517 | DTS Score=0.8693
# Epoch 91 Val: DTC Loss=3.7985 | DTC Score=0.9226 | DTS Loss=13.9258 | DTS Score=0.8398
#
# Epoch 92 Train: DTC Loss=3.4444 | DTC Score=0.9301 | DTS Loss=12.5653 | DTS Score=0.8764
# Epoch 92 Val: DTC Loss=3.4900 | DTC Score=0.9254 | DTS Loss=13.8461 | DTS Score=0.8356
#
# Epoch 93 Train: DTC Loss=3.4180 | DTC Score=0.9346 | DTS Loss=12.6214 | DTS Score=0.8732
# Epoch 93 Val: DTC Loss=3.5535 | DTC Score=0.9296 | DTS Loss=13.5314 | DTS Score=0.8539
#
# Epoch 94 Train: DTC Loss=3.5711 | DTC Score=0.9294 | DTS Loss=12.8395 | DTS Score=0.8645
# Epoch 94 Val: DTC Loss=3.3733 | DTC Score=0.9310 | DTS Loss=13.5830 | DTS Score=0.8566
#
# Epoch 95 Train: DTC Loss=3.4572 | DTC Score=0.9337 | DTS Loss=12.5092 | DTS Score=0.8692
# Epoch 95 Val: DTC Loss=3.6429 | DTC Score=0.9267 | DTS Loss=13.5044 | DTS Score=0.8466
#
# Epoch 96 Train: DTC Loss=3.4893 | DTC Score=0.9272 | DTS Loss=12.6371 | DTS Score=0.8662
# Epoch 96 Val: DTC Loss=3.5476 | DTC Score=0.9264 | DTS Loss=13.4840 | DTS Score=0.8439
#
# Epoch 97 Train: DTC Loss=3.5314 | DTC Score=0.9286 | DTS Loss=12.6316 | DTS Score=0.8706
# Epoch 97 Val: DTC Loss=3.8913 | DTC Score=0.9045 | DTS Loss=13.5636 | DTS Score=0.8445
#
# Epoch 98 Train: DTC Loss=3.4044 | DTC Score=0.9322 | DTS Loss=12.4700 | DTS Score=0.8739
# Epoch 98 Val: DTC Loss=3.6703 | DTC Score=0.9216 | DTS Loss=13.5706 | DTS Score=0.8437
#
# Model Saved
# Epoch 99 Train: DTC Loss=3.5626 | DTC Score=0.9291 | DTS Loss=12.7719 | DTS Score=0.8737
# Epoch 99 Val: DTC Loss=3.3440 | DTC Score=0.9409 | DTS Loss=13.3590 | DTS Score=0.8452
#
# Epoch 100 Train: DTC Loss=3.4580 | DTC Score=0.9301 | DTS Loss=12.5552 | DTS Score=0.8665
# Epoch 100 Val: DTC Loss=3.3701 | DTC Score=0.9347 | DTS Loss=13.6383 | DTS Score=0.8514
#
# Epoch 101 Train: DTC Loss=3.3500 | DTC Score=0.9378 | DTS Loss=12.2922 | DTS Score=0.8733
# Epoch 101 Val: DTC Loss=3.3855 | DTC Score=0.9293 | DTS Loss=13.6325 | DTS Score=0.8492
#
# Model Saved
# Epoch 102 Train: DTC Loss=3.4647 | DTC Score=0.9334 | DTS Loss=12.4347 | DTS Score=0.8706
# Epoch 102 Val: DTC Loss=3.2480 | DTC Score=0.9368 | DTS Loss=13.2362 | DTS Score=0.8483
#
# Epoch 103 Train: DTC Loss=3.4603 | DTC Score=0.9336 | DTS Loss=12.4262 | DTS Score=0.8764
# Epoch 103 Val: DTC Loss=3.3056 | DTC Score=0.9301 | DTS Loss=13.2779 | DTS Score=0.8410
#
# Epoch 104 Train: DTC Loss=3.3519 | DTC Score=0.9372 | DTS Loss=12.3509 | DTS Score=0.8701
# Epoch 104 Val: DTC Loss=3.4828 | DTC Score=0.9282 | DTS Loss=13.6866 | DTS Score=0.8465
#
# Epoch 105 Train: DTC Loss=3.5260 | DTC Score=0.9315 | DTS Loss=12.6592 | DTS Score=0.8696
# Epoch 105 Val: DTC Loss=3.4501 | DTC Score=0.9272 | DTS Loss=13.8469 | DTS Score=0.8423
#
# Epoch 106 Train: DTC Loss=3.3382 | DTC Score=0.9377 | DTS Loss=12.4239 | DTS Score=0.8757
# Epoch 106 Val: DTC Loss=3.5948 | DTC Score=0.9240 | DTS Loss=13.4184 | DTS Score=0.8531
#
# Epoch 107 Train: DTC Loss=3.4901 | DTC Score=0.9331 | DTS Loss=12.6607 | DTS Score=0.8684
# Epoch 107 Val: DTC Loss=3.6375 | DTC Score=0.9274 | DTS Loss=13.9385 | DTS Score=0.8384
#
# Epoch 108 Train: DTC Loss=3.4668 | DTC Score=0.9303 | DTS Loss=12.5212 | DTS Score=0.8748
# Epoch 108 Val: DTC Loss=3.5519 | DTC Score=0.9160 | DTS Loss=13.4637 | DTS Score=0.8332
#
# Epoch 109 Train: DTC Loss=3.5236 | DTC Score=0.9311 | DTS Loss=12.6167 | DTS Score=0.8729
# Epoch 109 Val: DTC Loss=3.6036 | DTC Score=0.9249 | DTS Loss=13.6342 | DTS Score=0.8393
#
# Epoch 110 Train: DTC Loss=3.4731 | DTC Score=0.9280 | DTS Loss=12.9110 | DTS Score=0.8600
# Epoch 110 Val: DTC Loss=3.8598 | DTC Score=0.9115 | DTS Loss=13.4672 | DTS Score=0.8585
#
# Epoch 111 Train: DTC Loss=3.5151 | DTC Score=0.9263 | DTS Loss=12.4728 | DTS Score=0.8707
# Epoch 111 Val: DTC Loss=3.4691 | DTC Score=0.9329 | DTS Loss=13.4696 | DTS Score=0.8471
#
# Epoch 112 Train: DTC Loss=3.5311 | DTC Score=0.9309 | DTS Loss=12.5920 | DTS Score=0.8773
# Epoch 112 Val: DTC Loss=3.4084 | DTC Score=0.9305 | DTS Loss=13.7237 | DTS Score=0.8480
#
# Epoch 113 Train: DTC Loss=3.5207 | DTC Score=0.9316 | DTS Loss=12.3888 | DTS Score=0.8704
# Epoch 113 Val: DTC Loss=3.4888 | DTC Score=0.9311 | DTS Loss=13.6524 | DTS Score=0.8466
#
# Epoch 114 Train: DTC Loss=3.5496 | DTC Score=0.9247 | DTS Loss=12.5275 | DTS Score=0.8666
# Epoch 114 Val: DTC Loss=3.6534 | DTC Score=0.9207 | DTS Loss=13.8829 | DTS Score=0.8477
#
# Epoch 115 Train: DTC Loss=3.5567 | DTC Score=0.9236 | DTS Loss=12.6783 | DTS Score=0.8691
# Epoch 115 Val: DTC Loss=3.5889 | DTC Score=0.9228 | DTS Loss=13.6434 | DTS Score=0.8481
#
# Model Saved
# Epoch 116 Train: DTC Loss=3.3407 | DTC Score=0.9336 | DTS Loss=12.4444 | DTS Score=0.8710
# Epoch 116 Val: DTC Loss=3.3789 | DTC Score=0.9312 | DTS Loss=12.9359 | DTS Score=0.8573
#
# Epoch 117 Train: DTC Loss=3.4656 | DTC Score=0.9332 | DTS Loss=12.5105 | DTS Score=0.8739
# Epoch 117 Val: DTC Loss=3.5842 | DTC Score=0.9234 | DTS Loss=13.6282 | DTS Score=0.8387
#
# Epoch 118 Train: DTC Loss=3.4980 | DTC Score=0.9316 | DTS Loss=12.4203 | DTS Score=0.8765
# Epoch 118 Val: DTC Loss=3.5132 | DTC Score=0.9258 | DTS Loss=13.5880 | DTS Score=0.8379
#
# Epoch 119 Train: DTC Loss=3.4608 | DTC Score=0.9334 | DTS Loss=12.6083 | DTS Score=0.8677
# Epoch 119 Val: DTC Loss=3.4870 | DTC Score=0.9299 | DTS Loss=13.3488 | DTS Score=0.8588
#
# Epoch 120 Train: DTC Loss=3.4546 | DTC Score=0.9327 | DTS Loss=12.3872 | DTS Score=0.8688
# Epoch 120 Val: DTC Loss=3.5087 | DTC Score=0.9212 | DTS Loss=13.3568 | DTS Score=0.8334
#
# Epoch 121 Train: DTC Loss=3.3989 | DTC Score=0.9335 | DTS Loss=12.2966 | DTS Score=0.8756
# Epoch 121 Val: DTC Loss=3.4964 | DTC Score=0.9218 | DTS Loss=13.6731 | DTS Score=0.8344
#
# Epoch 122 Train: DTC Loss=3.5118 | DTC Score=0.9301 | DTS Loss=12.4827 | DTS Score=0.8715
# Epoch 122 Val: DTC Loss=3.3834 | DTC Score=0.9382 | DTS Loss=13.3029 | DTS Score=0.8621
#
# Epoch 123 Train: DTC Loss=3.4022 | DTC Score=0.9350 | DTS Loss=12.5367 | DTS Score=0.8749
# Epoch 123 Val: DTC Loss=3.4936 | DTC Score=0.9300 | DTS Loss=13.3589 | DTS Score=0.8572
#
# Epoch 124 Train: DTC Loss=3.4261 | DTC Score=0.9355 | DTS Loss=12.3264 | DTS Score=0.8728
# Epoch 124 Val: DTC Loss=3.4491 | DTC Score=0.9302 | DTS Loss=13.7736 | DTS Score=0.8494
#
# Epoch 125 Train: DTC Loss=3.5515 | DTC Score=0.9285 | DTS Loss=12.4524 | DTS Score=0.8700
# Epoch 125 Val: DTC Loss=3.2929 | DTC Score=0.9375 | DTS Loss=13.0995 | DTS Score=0.8580
#
# Epoch 126 Train: DTC Loss=3.2908 | DTC Score=0.9371 | DTS Loss=12.1925 | DTS Score=0.8747
# Epoch 126 Val: DTC Loss=3.3948 | DTC Score=0.9367 | DTS Loss=13.6703 | DTS Score=0.8332
#
# Epoch 127 Train: DTC Loss=3.3652 | DTC Score=0.9321 | DTS Loss=12.1627 | DTS Score=0.8853
# Epoch 127 Val: DTC Loss=3.4646 | DTC Score=0.9313 | DTS Loss=13.3723 | DTS Score=0.8533
#
# Model Saved
# Epoch 128 Train: DTC Loss=3.2985 | DTC Score=0.9347 | DTS Loss=12.1185 | DTS Score=0.8770
# Epoch 128 Val: DTC Loss=3.2620 | DTC Score=0.9412 | DTS Loss=13.0495 | DTS Score=0.8634
#
# Epoch 129 Train: DTC Loss=3.3757 | DTC Score=0.9391 | DTS Loss=12.2139 | DTS Score=0.8882
# Epoch 129 Val: DTC Loss=3.3547 | DTC Score=0.9314 | DTS Loss=13.3347 | DTS Score=0.8516
#
# Epoch 130 Train: DTC Loss=3.3794 | DTC Score=0.9330 | DTS Loss=12.2258 | DTS Score=0.8779
# Epoch 130 Val: DTC Loss=3.3039 | DTC Score=0.9348 | DTS Loss=13.3825 | DTS Score=0.8584
#
# Epoch 131 Train: DTC Loss=3.4531 | DTC Score=0.9314 | DTS Loss=12.1676 | DTS Score=0.8720
# Epoch 131 Val: DTC Loss=3.5394 | DTC Score=0.9295 | DTS Loss=13.1248 | DTS Score=0.8601
#
# Epoch 132 Train: DTC Loss=3.4370 | DTC Score=0.9340 | DTS Loss=12.4046 | DTS Score=0.8701
# Epoch 132 Val: DTC Loss=3.4720 | DTC Score=0.9308 | DTS Loss=13.4258 | DTS Score=0.8490
#
# Epoch 133 Train: DTC Loss=3.3657 | DTC Score=0.9357 | DTS Loss=12.1768 | DTS Score=0.8730
# Epoch 133 Val: DTC Loss=3.3046 | DTC Score=0.9357 | DTS Loss=13.3766 | DTS Score=0.8568
#
# Epoch 134 Train: DTC Loss=3.4093 | DTC Score=0.9345 | DTS Loss=12.1147 | DTS Score=0.8794
# Epoch 134 Val: DTC Loss=3.3742 | DTC Score=0.9361 | DTS Loss=13.3454 | DTS Score=0.8521
#
# Epoch 135 Train: DTC Loss=3.2994 | DTC Score=0.9406 | DTS Loss=12.1849 | DTS Score=0.8781
# Epoch 135 Val: DTC Loss=3.3993 | DTC Score=0.9299 | DTS Loss=13.3958 | DTS Score=0.8523
#
# Epoch 136 Train: DTC Loss=3.4010 | DTC Score=0.9309 | DTS Loss=12.2106 | DTS Score=0.8715
# Epoch 136 Val: DTC Loss=3.6648 | DTC Score=0.9234 | DTS Loss=13.2788 | DTS Score=0.8578
#
# Epoch 137 Train: DTC Loss=3.2783 | DTC Score=0.9348 | DTS Loss=12.0831 | DTS Score=0.8804
# Epoch 137 Val: DTC Loss=3.6390 | DTC Score=0.9137 | DTS Loss=13.2155 | DTS Score=0.8493
#
# Epoch 138 Train: DTC Loss=3.4199 | DTC Score=0.9299 | DTS Loss=12.2746 | DTS Score=0.8841
# Epoch 138 Val: DTC Loss=3.5242 | DTC Score=0.9271 | DTS Loss=13.6067 | DTS Score=0.8454
#
# Epoch 139 Train: DTC Loss=3.4522 | DTC Score=0.9273 | DTS Loss=12.3810 | DTS Score=0.8662
# Epoch 139 Val: DTC Loss=3.4255 | DTC Score=0.9284 | DTS Loss=13.3952 | DTS Score=0.8588
#
# Epoch 140 Train: DTC Loss=3.3444 | DTC Score=0.9391 | DTS Loss=12.3030 | DTS Score=0.8771
# Epoch 140 Val: DTC Loss=3.5099 | DTC Score=0.9249 | DTS Loss=13.0713 | DTS Score=0.8477
#
# Epoch 141 Train: DTC Loss=3.4108 | DTC Score=0.9340 | DTS Loss=12.1344 | DTS Score=0.8711
# Epoch 141 Val: DTC Loss=3.5646 | DTC Score=0.9293 | DTS Loss=13.4818 | DTS Score=0.8408
#
# Epoch 142 Train: DTC Loss=3.2841 | DTC Score=0.9356 | DTS Loss=11.7549 | DTS Score=0.8859
# Epoch 142 Val: DTC Loss=3.5663 | DTC Score=0.9241 | DTS Loss=13.1532 | DTS Score=0.8524
#
# Epoch 143 Train: DTC Loss=3.3645 | DTC Score=0.9353 | DTS Loss=12.2078 | DTS Score=0.8805
# Epoch 143 Val: DTC Loss=3.4290 | DTC Score=0.9248 | DTS Loss=13.3831 | DTS Score=0.8436
#
# Model Saved
# Epoch 144 Train: DTC Loss=3.2960 | DTC Score=0.9403 | DTS Loss=12.0666 | DTS Score=0.8749
# Epoch 144 Val: DTC Loss=3.2837 | DTC Score=0.9325 | DTS Loss=12.9691 | DTS Score=0.8588
#
# Epoch 145 Train: DTC Loss=3.2735 | DTC Score=0.9380 | DTS Loss=11.9939 | DTS Score=0.8795
# Epoch 145 Val: DTC Loss=3.4498 | DTC Score=0.9304 | DTS Loss=13.0686 | DTS Score=0.8437
#
# Epoch 146 Train: DTC Loss=3.4972 | DTC Score=0.9290 | DTS Loss=12.1897 | DTS Score=0.8741
# Epoch 146 Val: DTC Loss=3.4129 | DTC Score=0.9376 | DTS Loss=13.1864 | DTS Score=0.8633
#
# Epoch 147 Train: DTC Loss=3.2967 | DTC Score=0.9382 | DTS Loss=11.9731 | DTS Score=0.8859
# Epoch 147 Val: DTC Loss=3.4322 | DTC Score=0.9282 | DTS Loss=13.3895 | DTS Score=0.8520
#
# Epoch 148 Train: DTC Loss=3.4662 | DTC Score=0.9320 | DTS Loss=12.0675 | DTS Score=0.8813
# Epoch 148 Val: DTC Loss=3.2743 | DTC Score=0.9369 | DTS Loss=12.9935 | DTS Score=0.8572
#
# Epoch 149 Train: DTC Loss=3.3144 | DTC Score=0.9377 | DTS Loss=11.7844 | DTS Score=0.8848
# Epoch 149 Val: DTC Loss=3.4332 | DTC Score=0.9347 | DTS Loss=13.6385 | DTS Score=0.8552
#
# Epoch 150 Train: DTC Loss=3.2873 | DTC Score=0.9376 | DTS Loss=11.8557 | DTS Score=0.8870
# Epoch 150 Val: DTC Loss=3.5602 | DTC Score=0.9235 | DTS Loss=13.3945 | DTS Score=0.8586
#
# Epoch 151 Train: DTC Loss=3.5084 | DTC Score=0.9344 | DTS Loss=12.1539 | DTS Score=0.8865
# Epoch 151 Val: DTC Loss=3.3291 | DTC Score=0.9337 | DTS Loss=13.1269 | DTS Score=0.8596
#
# Epoch 152 Train: DTC Loss=3.5379 | DTC Score=0.9330 | DTS Loss=12.0784 | DTS Score=0.8760
# Epoch 152 Val: DTC Loss=3.5514 | DTC Score=0.9267 | DTS Loss=13.2771 | DTS Score=0.8588
#
# Epoch 153 Train: DTC Loss=3.3401 | DTC Score=0.9363 | DTS Loss=12.1117 | DTS Score=0.8794
# Epoch 153 Val: DTC Loss=3.4046 | DTC Score=0.9334 | DTS Loss=13.8104 | DTS Score=0.8635
#
# Epoch 154 Train: DTC Loss=3.3718 | DTC Score=0.9348 | DTS Loss=12.1282 | DTS Score=0.8788
# Epoch 154 Val: DTC Loss=3.2907 | DTC Score=0.9346 | DTS Loss=13.2769 | DTS Score=0.8585
#
# Epoch 155 Train: DTC Loss=3.2749 | DTC Score=0.9356 | DTS Loss=11.6871 | DTS Score=0.8794
# Epoch 155 Val: DTC Loss=3.2346 | DTC Score=0.9432 | DTS Loss=13.1631 | DTS Score=0.8610
#
# Epoch 156 Train: DTC Loss=3.3826 | DTC Score=0.9374 | DTS Loss=12.2339 | DTS Score=0.8798
# Epoch 156 Val: DTC Loss=3.3344 | DTC Score=0.9319 | DTS Loss=13.2661 | DTS Score=0.8559
#
# Epoch 157 Train: DTC Loss=3.4041 | DTC Score=0.9333 | DTS Loss=11.8939 | DTS Score=0.8792
# Epoch 157 Val: DTC Loss=3.3002 | DTC Score=0.9398 | DTS Loss=13.1251 | DTS Score=0.8492
#
# Epoch 158 Train: DTC Loss=3.3499 | DTC Score=0.9409 | DTS Loss=12.0334 | DTS Score=0.8839
# Epoch 158 Val: DTC Loss=3.7066 | DTC Score=0.9216 | DTS Loss=13.8924 | DTS Score=0.8374
#
# Epoch 159 Train: DTC Loss=3.3645 | DTC Score=0.9320 | DTS Loss=11.9703 | DTS Score=0.8850
# Epoch 159 Val: DTC Loss=3.3753 | DTC Score=0.9335 | DTS Loss=13.3258 | DTS Score=0.8631
#
# Epoch 160 Train: DTC Loss=3.3254 | DTC Score=0.9355 | DTS Loss=12.0376 | DTS Score=0.8796
# Epoch 160 Val: DTC Loss=3.6428 | DTC Score=0.9093 | DTS Loss=13.5079 | DTS Score=0.8461
#
# Epoch 161 Train: DTC Loss=3.3539 | DTC Score=0.9376 | DTS Loss=12.0979 | DTS Score=0.8806
# Epoch 161 Val: DTC Loss=3.3594 | DTC Score=0.9306 | DTS Loss=13.1369 | DTS Score=0.8731
#
# Epoch 162 Train: DTC Loss=3.3054 | DTC Score=0.9346 | DTS Loss=11.7926 | DTS Score=0.8825
# Epoch 162 Val: DTC Loss=3.3081 | DTC Score=0.9348 | DTS Loss=13.4265 | DTS Score=0.8490
#
# Epoch 163 Train: DTC Loss=3.2397 | DTC Score=0.9404 | DTS Loss=11.8365 | DTS Score=0.8839
# Epoch 163 Val: DTC Loss=3.3206 | DTC Score=0.9339 | DTS Loss=13.1179 | DTS Score=0.8491
#
# Epoch 164 Train: DTC Loss=3.4787 | DTC Score=0.9359 | DTS Loss=12.0544 | DTS Score=0.8849
# Epoch 164 Val: DTC Loss=3.3495 | DTC Score=0.9404 | DTS Loss=13.2316 | DTS Score=0.8666
#
# Epoch 165 Train: DTC Loss=3.3760 | DTC Score=0.9322 | DTS Loss=12.0382 | DTS Score=0.8811
# Epoch 165 Val: DTC Loss=3.8787 | DTC Score=0.9124 | DTS Loss=13.9735 | DTS Score=0.8274
#
# Epoch 166 Train: DTC Loss=3.3792 | DTC Score=0.9336 | DTS Loss=12.1020 | DTS Score=0.8796
# Epoch 166 Val: DTC Loss=3.4193 | DTC Score=0.9295 | DTS Loss=13.4339 | DTS Score=0.8696
#
# Model Saved
# Epoch 167 Train: DTC Loss=3.2269 | DTC Score=0.9400 | DTS Loss=11.7183 | DTS Score=0.8864
# Epoch 167 Val: DTC Loss=3.2403 | DTC Score=0.9354 | DTS Loss=12.7847 | DTS Score=0.8542
#
# Epoch 168 Train: DTC Loss=3.2997 | DTC Score=0.9399 | DTS Loss=11.8182 | DTS Score=0.8851
# Epoch 168 Val: DTC Loss=3.8818 | DTC Score=0.9097 | DTS Loss=13.6265 | DTS Score=0.8472
#
# Epoch 169 Train: DTC Loss=3.4179 | DTC Score=0.9313 | DTS Loss=11.8797 | DTS Score=0.8862
# Epoch 169 Val: DTC Loss=3.4051 | DTC Score=0.9291 | DTS Loss=13.2038 | DTS Score=0.8684
#
# Epoch 170 Train: DTC Loss=3.3218 | DTC Score=0.9380 | DTS Loss=11.9940 | DTS Score=0.8811
# Epoch 170 Val: DTC Loss=3.7259 | DTC Score=0.9157 | DTS Loss=13.4675 | DTS Score=0.8449
#
# Epoch 171 Train: DTC Loss=3.5191 | DTC Score=0.9307 | DTS Loss=11.9780 | DTS Score=0.8838
# Epoch 171 Val: DTC Loss=3.5068 | DTC Score=0.9290 | DTS Loss=13.2713 | DTS Score=0.8513
#
# Epoch 172 Train: DTC Loss=3.3511 | DTC Score=0.9316 | DTS Loss=11.9264 | DTS Score=0.8772
# Epoch 172 Val: DTC Loss=3.4150 | DTC Score=0.9322 | DTS Loss=13.4375 | DTS Score=0.8392
#
# Epoch 173 Train: DTC Loss=3.3075 | DTC Score=0.9386 | DTS Loss=11.7909 | DTS Score=0.8829
# Epoch 173 Val: DTC Loss=3.3631 | DTC Score=0.9322 | DTS Loss=13.2503 | DTS Score=0.8515
#
# Epoch 174 Train: DTC Loss=3.2407 | DTC Score=0.9357 | DTS Loss=11.8638 | DTS Score=0.8833
# Epoch 174 Val: DTC Loss=3.4924 | DTC Score=0.9288 | DTS Loss=13.1156 | DTS Score=0.8505
#
# Epoch 175 Train: DTC Loss=3.3232 | DTC Score=0.9329 | DTS Loss=11.6842 | DTS Score=0.8843
# Epoch 175 Val: DTC Loss=3.4668 | DTC Score=0.9307 | DTS Loss=13.0671 | DTS Score=0.8530
#
# Epoch 176 Train: DTC Loss=3.2197 | DTC Score=0.9409 | DTS Loss=11.5907 | DTS Score=0.8937
# Epoch 176 Val: DTC Loss=3.4591 | DTC Score=0.9347 | DTS Loss=13.0121 | DTS Score=0.8524
#
# Epoch 177 Train: DTC Loss=3.2437 | DTC Score=0.9368 | DTS Loss=11.7114 | DTS Score=0.8890
# Epoch 177 Val: DTC Loss=3.4387 | DTC Score=0.9340 | DTS Loss=13.5154 | DTS Score=0.8542
#
# Epoch 178 Train: DTC Loss=3.2553 | DTC Score=0.9384 | DTS Loss=11.7328 | DTS Score=0.8930
# Epoch 178 Val: DTC Loss=3.3327 | DTC Score=0.9363 | DTS Loss=12.9931 | DTS Score=0.8614
#
# Epoch 179 Train: DTC Loss=3.3024 | DTC Score=0.9381 | DTS Loss=11.8376 | DTS Score=0.8943
# Epoch 179 Val: DTC Loss=3.3048 | DTC Score=0.9332 | DTS Loss=13.1945 | DTS Score=0.8567
#
# Epoch 180 Train: DTC Loss=3.3034 | DTC Score=0.9370 | DTS Loss=11.8217 | DTS Score=0.8835
# Epoch 180 Val: DTC Loss=3.3660 | DTC Score=0.9299 | DTS Loss=13.2472 | DTS Score=0.8306
#
# Epoch 181 Train: DTC Loss=3.2401 | DTC Score=0.9385 | DTS Loss=11.6133 | DTS Score=0.8978
# Epoch 181 Val: DTC Loss=3.3515 | DTC Score=0.9311 | DTS Loss=13.2281 | DTS Score=0.8481
#
# Epoch 182 Train: DTC Loss=3.3863 | DTC Score=0.9352 | DTS Loss=11.8496 | DTS Score=0.8855
# Epoch 182 Val: DTC Loss=3.2823 | DTC Score=0.9332 | DTS Loss=13.0120 | DTS Score=0.8618
#
# Epoch 183 Train: DTC Loss=3.2628 | DTC Score=0.9411 | DTS Loss=11.6684 | DTS Score=0.8957
# Epoch 183 Val: DTC Loss=3.3968 | DTC Score=0.9369 | DTS Loss=13.2656 | DTS Score=0.8490
#
# Epoch 184 Train: DTC Loss=3.2284 | DTC Score=0.9401 | DTS Loss=11.6516 | DTS Score=0.8888
# Epoch 184 Val: DTC Loss=3.2766 | DTC Score=0.9362 | DTS Loss=13.2274 | DTS Score=0.8604
#
# Epoch 185 Train: DTC Loss=3.2136 | DTC Score=0.9383 | DTS Loss=11.4384 | DTS Score=0.8906
# Epoch 185 Val: DTC Loss=3.3315 | DTC Score=0.9306 | DTS Loss=12.8402 | DTS Score=0.8623
#
# Epoch 186 Train: DTC Loss=3.2409 | DTC Score=0.9390 | DTS Loss=11.5611 | DTS Score=0.8953
# Epoch 186 Val: DTC Loss=3.2863 | DTC Score=0.9401 | DTS Loss=13.4421 | DTS Score=0.8628
#
# Epoch 187 Train: DTC Loss=3.3272 | DTC Score=0.9364 | DTS Loss=11.8118 | DTS Score=0.8802
# Epoch 187 Val: DTC Loss=3.3440 | DTC Score=0.9367 | DTS Loss=13.4193 | DTS Score=0.8517
#
# Epoch 188 Train: DTC Loss=3.2343 | DTC Score=0.9408 | DTS Loss=11.5539 | DTS Score=0.8875
# Epoch 188 Val: DTC Loss=3.3293 | DTC Score=0.9319 | DTS Loss=12.9694 | DTS Score=0.8584
#
# Epoch 189 Train: DTC Loss=3.2233 | DTC Score=0.9394 | DTS Loss=11.7923 | DTS Score=0.8915
# Epoch 189 Val: DTC Loss=3.3986 | DTC Score=0.9336 | DTS Loss=12.9440 | DTS Score=0.8545
#
# Epoch 190 Train: DTC Loss=3.2503 | DTC Score=0.9405 | DTS Loss=11.7615 | DTS Score=0.8857
# Epoch 190 Val: DTC Loss=3.2068 | DTC Score=0.9398 | DTS Loss=13.1933 | DTS Score=0.8680
#
# Epoch 191 Train: DTC Loss=3.2510 | DTC Score=0.9425 | DTS Loss=11.6888 | DTS Score=0.8909
# Epoch 191 Val: DTC Loss=3.4304 | DTC Score=0.9323 | DTS Loss=13.5418 | DTS Score=0.8495
#
# Epoch 192 Train: DTC Loss=3.3140 | DTC Score=0.9376 | DTS Loss=11.6260 | DTS Score=0.8867
# Epoch 192 Val: DTC Loss=3.3238 | DTC Score=0.9377 | DTS Loss=13.2578 | DTS Score=0.8588
#
# Epoch 193 Train: DTC Loss=3.2472 | DTC Score=0.9385 | DTS Loss=11.6722 | DTS Score=0.8879
# Epoch 193 Val: DTC Loss=3.4151 | DTC Score=0.9330 | DTS Loss=13.2428 | DTS Score=0.8542
#
# Epoch 194 Train: DTC Loss=3.2392 | DTC Score=0.9426 | DTS Loss=11.6512 | DTS Score=0.8921
# Epoch 194 Val: DTC Loss=3.5431 | DTC Score=0.9243 | DTS Loss=13.4832 | DTS Score=0.8487
#
# Epoch 195 Train: DTC Loss=3.1873 | DTC Score=0.9389 | DTS Loss=11.5289 | DTS Score=0.8829
# Epoch 195 Val: DTC Loss=3.3528 | DTC Score=0.9314 | DTS Loss=13.2945 | DTS Score=0.8533
#
# Epoch 196 Train: DTC Loss=3.4517 | DTC Score=0.9306 | DTS Loss=11.9646 | DTS Score=0.8792
# Epoch 196 Val: DTC Loss=3.4064 | DTC Score=0.9304 | DTS Loss=13.0386 | DTS Score=0.8669
#
# Epoch 197 Train: DTC Loss=3.2789 | DTC Score=0.9391 | DTS Loss=11.6126 | DTS Score=0.8911
# Epoch 197 Val: DTC Loss=3.2918 | DTC Score=0.9388 | DTS Loss=12.7955 | DTS Score=0.8641
#
# Epoch 198 Train: DTC Loss=3.3304 | DTC Score=0.9416 | DTS Loss=11.7908 | DTS Score=0.8855
# Epoch 198 Val: DTC Loss=3.3669 | DTC Score=0.9297 | DTS Loss=13.6265 | DTS Score=0.8502
#
# Epoch 199 Train: DTC Loss=3.2833 | DTC Score=0.9398 | DTS Loss=11.7253 | DTS Score=0.8868
# Epoch 199 Val: DTC Loss=3.4470 | DTC Score=0.9341 | DTS Loss=12.9863 | DTS Score=0.8559
#
# Epoch 200 Train: DTC Loss=3.2326 | DTC Score=0.9386 | DTS Loss=11.6986 | DTS Score=0.8862
# Epoch 200 Val: DTC Loss=3.3559 | DTC Score=0.9330 | DTS Loss=13.0205 | DTS Score=0.8628
#
# Epoch 201 Train: DTC Loss=3.2810 | DTC Score=0.9386 | DTS Loss=11.5067 | DTS Score=0.8979
# Epoch 201 Val: DTC Loss=3.2677 | DTC Score=0.9373 | DTS Loss=13.0840 | DTS Score=0.8550
#
# Epoch 202 Train: DTC Loss=3.2167 | DTC Score=0.9411 | DTS Loss=11.3526 | DTS Score=0.8910
# Epoch 202 Val: DTC Loss=3.2215 | DTC Score=0.9396 | DTS Loss=12.8570 | DTS Score=0.8605
#
# Epoch 203 Train: DTC Loss=3.2296 | DTC Score=0.9403 | DTS Loss=11.6445 | DTS Score=0.8829
# Epoch 203 Val: DTC Loss=3.3669 | DTC Score=0.9292 | DTS Loss=13.1429 | DTS Score=0.8586
#
# Epoch 204 Train: DTC Loss=3.2495 | DTC Score=0.9371 | DTS Loss=11.3619 | DTS Score=0.8949
# Epoch 204 Val: DTC Loss=3.3236 | DTC Score=0.9350 | DTS Loss=12.9537 | DTS Score=0.8530
#
# Epoch 205 Train: DTC Loss=3.1649 | DTC Score=0.9417 | DTS Loss=11.3566 | DTS Score=0.8947
# Epoch 205 Val: DTC Loss=3.4088 | DTC Score=0.9312 | DTS Loss=13.2712 | DTS Score=0.8408
#
# Epoch 206 Train: DTC Loss=3.2890 | DTC Score=0.9370 | DTS Loss=11.6439 | DTS Score=0.8935
# Epoch 206 Val: DTC Loss=3.5662 | DTC Score=0.9281 | DTS Loss=13.6617 | DTS Score=0.8551
#
# Epoch 207 Train: DTC Loss=3.2714 | DTC Score=0.9357 | DTS Loss=11.6335 | DTS Score=0.8858
# Epoch 207 Val: DTC Loss=3.3078 | DTC Score=0.9368 | DTS Loss=13.2480 | DTS Score=0.8499
#
# Epoch 208 Train: DTC Loss=3.3230 | DTC Score=0.9370 | DTS Loss=11.5842 | DTS Score=0.8927
# Epoch 208 Val: DTC Loss=3.7685 | DTC Score=0.9192 | DTS Loss=13.3893 | DTS Score=0.8481
#
# Epoch 209 Train: DTC Loss=3.3817 | DTC Score=0.9332 | DTS Loss=11.7893 | DTS Score=0.8899
# Epoch 209 Val: DTC Loss=3.3778 | DTC Score=0.9309 | DTS Loss=13.0459 | DTS Score=0.8669
#
# Epoch 210 Train: DTC Loss=3.2257 | DTC Score=0.9405 | DTS Loss=11.5124 | DTS Score=0.8894
# Epoch 210 Val: DTC Loss=3.2986 | DTC Score=0.9368 | DTS Loss=13.2370 | DTS Score=0.8503
#
# Epoch 211 Train: DTC Loss=3.1884 | DTC Score=0.9430 | DTS Loss=11.2346 | DTS Score=0.8989
# Epoch 211 Val: DTC Loss=3.2217 | DTC Score=0.9440 | DTS Loss=12.9569 | DTS Score=0.8640
#
# Epoch 212 Train: DTC Loss=3.2644 | DTC Score=0.9393 | DTS Loss=11.7391 | DTS Score=0.8863
# Epoch 212 Val: DTC Loss=3.2800 | DTC Score=0.9403 | DTS Loss=13.3896 | DTS Score=0.8518
#
# Epoch 213 Train: DTC Loss=3.2689 | DTC Score=0.9397 | DTS Loss=11.5019 | DTS Score=0.8890
# Epoch 213 Val: DTC Loss=3.3751 | DTC Score=0.9372 | DTS Loss=13.0463 | DTS Score=0.8513
#
# Epoch 214 Train: DTC Loss=3.1921 | DTC Score=0.9443 | DTS Loss=11.3712 | DTS Score=0.8909
# Epoch 214 Val: DTC Loss=3.5179 | DTC Score=0.9259 | DTS Loss=13.0738 | DTS Score=0.8521
#
# Epoch 215 Train: DTC Loss=3.2155 | DTC Score=0.9444 | DTS Loss=11.5036 | DTS Score=0.8894
# Epoch 215 Val: DTC Loss=3.2958 | DTC Score=0.9351 | DTS Loss=12.9042 | DTS Score=0.8443
#
# Epoch 216 Train: DTC Loss=3.2733 | DTC Score=0.9393 | DTS Loss=11.5968 | DTS Score=0.8955
# Epoch 216 Val: DTC Loss=3.4124 | DTC Score=0.9299 | DTS Loss=13.1584 | DTS Score=0.8495
#
# Epoch 217 Train: DTC Loss=3.2579 | DTC Score=0.9370 | DTS Loss=11.3997 | DTS Score=0.8955
# Epoch 217 Val: DTC Loss=3.2546 | DTC Score=0.9400 | DTS Loss=12.9361 | DTS Score=0.8630
#
# Epoch 218 Train: DTC Loss=3.2581 | DTC Score=0.9376 | DTS Loss=11.4952 | DTS Score=0.8878
# Epoch 218 Val: DTC Loss=3.3053 | DTC Score=0.9379 | DTS Loss=12.8385 | DTS Score=0.8727
#
# Epoch 219 Train: DTC Loss=3.1389 | DTC Score=0.9429 | DTS Loss=11.3656 | DTS Score=0.8981
# Epoch 219 Val: DTC Loss=3.2021 | DTC Score=0.9412 | DTS Loss=13.1416 | DTS Score=0.8648
#
# Epoch 220 Train: DTC Loss=3.2940 | DTC Score=0.9405 | DTS Loss=11.5279 | DTS Score=0.8895
# Epoch 220 Val: DTC Loss=3.2503 | DTC Score=0.9387 | DTS Loss=13.1092 | DTS Score=0.8569
#
# Epoch 221 Train: DTC Loss=3.1645 | DTC Score=0.9436 | DTS Loss=11.3486 | DTS Score=0.8967
# Epoch 221 Val: DTC Loss=3.3158 | DTC Score=0.9376 | DTS Loss=12.8159 | DTS Score=0.8759
#
# Epoch 222 Train: DTC Loss=3.2863 | DTC Score=0.9422 | DTS Loss=11.5469 | DTS Score=0.8924
# Epoch 222 Val: DTC Loss=3.2549 | DTC Score=0.9384 | DTS Loss=12.8130 | DTS Score=0.8675
#
# Epoch 223 Train: DTC Loss=3.1789 | DTC Score=0.9412 | DTS Loss=11.3709 | DTS Score=0.8888
# Epoch 223 Val: DTC Loss=3.3417 | DTC Score=0.9393 | DTS Loss=13.2590 | DTS Score=0.8710
#
# Epoch 224 Train: DTC Loss=3.1859 | DTC Score=0.9417 | DTS Loss=11.4872 | DTS Score=0.8903
# Epoch 224 Val: DTC Loss=3.4735 | DTC Score=0.9272 | DTS Loss=13.7531 | DTS Score=0.8451
#
# Epoch 225 Train: DTC Loss=3.2291 | DTC Score=0.9388 | DTS Loss=11.4162 | DTS Score=0.8956
# Epoch 225 Val: DTC Loss=3.3408 | DTC Score=0.9397 | DTS Loss=13.7036 | DTS Score=0.8458
#
# Epoch 226 Train: DTC Loss=3.2595 | DTC Score=0.9411 | DTS Loss=11.2545 | DTS Score=0.8975
# Epoch 226 Val: DTC Loss=3.7027 | DTC Score=0.9154 | DTS Loss=12.8255 | DTS Score=0.8499
#
# Epoch 227 Train: DTC Loss=3.2857 | DTC Score=0.9367 | DTS Loss=11.5618 | DTS Score=0.8929
# Epoch 227 Val: DTC Loss=3.3127 | DTC Score=0.9356 | DTS Loss=13.2045 | DTS Score=0.8719
#
# Epoch 228 Train: DTC Loss=3.3042 | DTC Score=0.9355 | DTS Loss=11.4746 | DTS Score=0.8941
# Epoch 228 Val: DTC Loss=3.3159 | DTC Score=0.9346 | DTS Loss=12.7935 | DTS Score=0.8528
#
# Epoch 229 Train: DTC Loss=3.3657 | DTC Score=0.9393 | DTS Loss=11.5941 | DTS Score=0.8941
# Epoch 229 Val: DTC Loss=3.4421 | DTC Score=0.9279 | DTS Loss=12.9146 | DTS Score=0.8571
#
# Epoch 230 Train: DTC Loss=3.2072 | DTC Score=0.9379 | DTS Loss=11.3462 | DTS Score=0.8869
# Epoch 230 Val: DTC Loss=3.4079 | DTC Score=0.9337 | DTS Loss=13.2234 | DTS Score=0.8594
#
# Epoch 231 Train: DTC Loss=3.2277 | DTC Score=0.9400 | DTS Loss=11.4210 | DTS Score=0.8945
# Epoch 231 Val: DTC Loss=3.3282 | DTC Score=0.9321 | DTS Loss=13.0459 | DTS Score=0.8602
#
# Epoch 232 Train: DTC Loss=3.2139 | DTC Score=0.9379 | DTS Loss=11.3254 | DTS Score=0.8866
# Epoch 232 Val: DTC Loss=3.3152 | DTC Score=0.9327 | DTS Loss=12.7235 | DTS Score=0.8445
#
# Epoch 233 Train: DTC Loss=3.1907 | DTC Score=0.9427 | DTS Loss=11.5297 | DTS Score=0.8905
# Epoch 233 Val: DTC Loss=3.2612 | DTC Score=0.9366 | DTS Loss=13.1962 | DTS Score=0.8547
#
# Epoch 234 Train: DTC Loss=3.2716 | DTC Score=0.9425 | DTS Loss=11.2448 | DTS Score=0.8960
# Epoch 234 Val: DTC Loss=3.3670 | DTC Score=0.9329 | DTS Loss=13.2260 | DTS Score=0.8599
#
# Epoch 235 Train: DTC Loss=3.2367 | DTC Score=0.9422 | DTS Loss=11.2440 | DTS Score=0.8881
# Epoch 235 Val: DTC Loss=3.4582 | DTC Score=0.9299 | DTS Loss=12.9845 | DTS Score=0.8561
#
# Epoch 236 Train: DTC Loss=3.2184 | DTC Score=0.9398 | DTS Loss=11.4061 | DTS Score=0.8953
# Epoch 236 Val: DTC Loss=3.4996 | DTC Score=0.9302 | DTS Loss=13.3543 | DTS Score=0.8525
#
# Epoch 237 Train: DTC Loss=3.3383 | DTC Score=0.9328 | DTS Loss=11.6032 | DTS Score=0.8944
# Epoch 237 Val: DTC Loss=3.3258 | DTC Score=0.9388 | DTS Loss=13.1141 | DTS Score=0.8556
#
# Epoch 238 Train: DTC Loss=3.2295 | DTC Score=0.9383 | DTS Loss=11.3700 | DTS Score=0.8920
# Epoch 238 Val: DTC Loss=3.2967 | DTC Score=0.9297 | DTS Loss=13.0524 | DTS Score=0.8575
#
# Epoch 239 Train: DTC Loss=3.2005 | DTC Score=0.9425 | DTS Loss=11.5604 | DTS Score=0.8954
# Epoch 239 Val: DTC Loss=3.2473 | DTC Score=0.9376 | DTS Loss=12.9483 | DTS Score=0.8523
#
# Epoch 240 Train: DTC Loss=3.2858 | DTC Score=0.9404 | DTS Loss=11.4607 | DTS Score=0.8918
# Epoch 240 Val: DTC Loss=3.3901 | DTC Score=0.9261 | DTS Loss=13.0922 | DTS Score=0.8510
#
# Epoch 241 Train: DTC Loss=3.1991 | DTC Score=0.9433 | DTS Loss=11.1621 | DTS Score=0.8934
# Epoch 241 Val: DTC Loss=3.7022 | DTC Score=0.9222 | DTS Loss=13.1277 | DTS Score=0.8720
#
# Epoch 242 Train: DTC Loss=3.2271 | DTC Score=0.9395 | DTS Loss=11.1705 | DTS Score=0.8981
# Epoch 242 Val: DTC Loss=3.2753 | DTC Score=0.9375 | DTS Loss=13.3222 | DTS Score=0.8409
#
# Epoch 243 Train: DTC Loss=3.2716 | DTC Score=0.9384 | DTS Loss=11.4557 | DTS Score=0.8885
# Epoch 243 Val: DTC Loss=3.3050 | DTC Score=0.9374 | DTS Loss=13.4546 | DTS Score=0.8534
#
# Epoch 244 Train: DTC Loss=3.1643 | DTC Score=0.9403 | DTS Loss=11.2424 | DTS Score=0.8940
# Epoch 244 Val: DTC Loss=3.3357 | DTC Score=0.9352 | DTS Loss=13.2062 | DTS Score=0.8555
#
# Epoch 245 Train: DTC Loss=3.1030 | DTC Score=0.9439 | DTS Loss=11.2337 | DTS Score=0.8998
# Epoch 245 Val: DTC Loss=3.2756 | DTC Score=0.9325 | DTS Loss=12.8054 | DTS Score=0.8669
#
# Epoch 246 Train: DTC Loss=3.2510 | DTC Score=0.9408 | DTS Loss=11.4108 | DTS Score=0.8905
# Epoch 246 Val: DTC Loss=3.3071 | DTC Score=0.9359 | DTS Loss=13.2321 | DTS Score=0.8427
#
# Epoch 247 Train: DTC Loss=3.1369 | DTC Score=0.9420 | DTS Loss=11.4628 | DTS Score=0.8846
# Epoch 247 Val: DTC Loss=3.3091 | DTC Score=0.9309 | DTS Loss=12.8434 | DTS Score=0.8700
#
# Epoch 248 Train: DTC Loss=3.1245 | DTC Score=0.9434 | DTS Loss=11.2253 | DTS Score=0.8981
# Epoch 248 Val: DTC Loss=3.4942 | DTC Score=0.9309 | DTS Loss=12.8349 | DTS Score=0.8764
#
# Epoch 249 Train: DTC Loss=3.1737 | DTC Score=0.9417 | DTS Loss=11.3540 | DTS Score=0.8935
# Epoch 249 Val: DTC Loss=3.2467 | DTC Score=0.9315 | DTS Loss=12.8561 | DTS Score=0.8606
#
# Epoch 250 Train: DTC Loss=3.2272 | DTC Score=0.9392 | DTS Loss=11.4447 | DTS Score=0.8860
# Epoch 250 Val: DTC Loss=3.9554 | DTC Score=0.9098 | DTS Loss=12.8735 | DTS Score=0.8597
#
# Epoch 251 Train: DTC Loss=3.1802 | DTC Score=0.9361 | DTS Loss=11.1945 | DTS Score=0.8920
# Epoch 251 Val: DTC Loss=3.4311 | DTC Score=0.9323 | DTS Loss=13.2962 | DTS Score=0.8518
#
# Epoch 252 Train: DTC Loss=3.2250 | DTC Score=0.9388 | DTS Loss=11.4390 | DTS Score=0.8938
# Epoch 252 Val: DTC Loss=3.5297 | DTC Score=0.9283 | DTS Loss=12.7983 | DTS Score=0.8780
#
# Epoch 253 Train: DTC Loss=3.2273 | DTC Score=0.9384 | DTS Loss=11.3864 | DTS Score=0.8962
# Epoch 253 Val: DTC Loss=3.1706 | DTC Score=0.9399 | DTS Loss=12.8825 | DTS Score=0.8509
#
# Epoch 254 Train: DTC Loss=3.1213 | DTC Score=0.9461 | DTS Loss=11.0869 | DTS Score=0.8992
# Epoch 254 Val: DTC Loss=3.4400 | DTC Score=0.9349 | DTS Loss=13.2328 | DTS Score=0.8594
#
# Epoch 255 Train: DTC Loss=3.1828 | DTC Score=0.9435 | DTS Loss=11.1777 | DTS Score=0.8981
# Epoch 255 Val: DTC Loss=3.3138 | DTC Score=0.9361 | DTS Loss=13.1543 | DTS Score=0.8527
#
# Model Saved
# Epoch 256 Train: DTC Loss=3.0922 | DTC Score=0.9439 | DTS Loss=11.2672 | DTS Score=0.9012
# Epoch 256 Val: DTC Loss=3.2617 | DTC Score=0.9371 | DTS Loss=12.6015 | DTS Score=0.8836
#
# Epoch 257 Train: DTC Loss=3.1486 | DTC Score=0.9431 | DTS Loss=11.1117 | DTS Score=0.8962
# Epoch 257 Val: DTC Loss=3.9205 | DTC Score=0.9008 | DTS Loss=13.6253 | DTS Score=0.8313
#
# Epoch 258 Train: DTC Loss=3.1632 | DTC Score=0.9379 | DTS Loss=11.2409 | DTS Score=0.8954
# Epoch 258 Val: DTC Loss=3.2284 | DTC Score=0.9400 | DTS Loss=12.6775 | DTS Score=0.8747
#
# Epoch 259 Train: DTC Loss=3.2439 | DTC Score=0.9396 | DTS Loss=11.2258 | DTS Score=0.8934
# Epoch 259 Val: DTC Loss=3.2174 | DTC Score=0.9454 | DTS Loss=12.7919 | DTS Score=0.8822
#
# Epoch 260 Train: DTC Loss=3.1693 | DTC Score=0.9449 | DTS Loss=11.2943 | DTS Score=0.8959
# Epoch 260 Val: DTC Loss=3.2637 | DTC Score=0.9357 | DTS Loss=13.1497 | DTS Score=0.8540
#
# Epoch 261 Train: DTC Loss=3.1477 | DTC Score=0.9446 | DTS Loss=11.2322 | DTS Score=0.8882
# Epoch 261 Val: DTC Loss=3.3541 | DTC Score=0.9360 | DTS Loss=12.9311 | DTS Score=0.8680
#
# Epoch 262 Train: DTC Loss=3.1149 | DTC Score=0.9448 | DTS Loss=11.1848 | DTS Score=0.8938
# Epoch 262 Val: DTC Loss=3.2782 | DTC Score=0.9365 | DTS Loss=12.8598 | DTS Score=0.8658
#
# Epoch 263 Train: DTC Loss=3.1483 | DTC Score=0.9440 | DTS Loss=11.0997 | DTS Score=0.8994
# Epoch 263 Val: DTC Loss=3.4257 | DTC Score=0.9324 | DTS Loss=13.1530 | DTS Score=0.8443
#
# Epoch 264 Train: DTC Loss=3.1909 | DTC Score=0.9386 | DTS Loss=11.3085 | DTS Score=0.8951
# Epoch 264 Val: DTC Loss=3.2312 | DTC Score=0.9387 | DTS Loss=12.8947 | DTS Score=0.8634
#
# Epoch 265 Train: DTC Loss=3.1726 | DTC Score=0.9426 | DTS Loss=11.2892 | DTS Score=0.8979
# Epoch 265 Val: DTC Loss=3.3412 | DTC Score=0.9351 | DTS Loss=13.0674 | DTS Score=0.8565
#
# Epoch 266 Train: DTC Loss=3.2034 | DTC Score=0.9421 | DTS Loss=11.2262 | DTS Score=0.8937
# Epoch 266 Val: DTC Loss=3.2696 | DTC Score=0.9365 | DTS Loss=12.8547 | DTS Score=0.8704
#
# Epoch 267 Train: DTC Loss=3.0737 | DTC Score=0.9460 | DTS Loss=11.0785 | DTS Score=0.8961
# Epoch 267 Val: DTC Loss=3.2347 | DTC Score=0.9380 | DTS Loss=13.1138 | DTS Score=0.8698
#
# Epoch 268 Train: DTC Loss=3.1423 | DTC Score=0.9444 | DTS Loss=11.1326 | DTS Score=0.8989
# Epoch 268 Val: DTC Loss=3.2291 | DTC Score=0.9395 | DTS Loss=12.9672 | DTS Score=0.8509
#
# Epoch 269 Train: DTC Loss=3.1434 | DTC Score=0.9432 | DTS Loss=11.1434 | DTS Score=0.8940
# Epoch 269 Val: DTC Loss=3.1695 | DTC Score=0.9450 | DTS Loss=12.9040 | DTS Score=0.8777
#
# Epoch 270 Train: DTC Loss=3.0831 | DTC Score=0.9473 | DTS Loss=11.2116 | DTS Score=0.8986
# Epoch 270 Val: DTC Loss=3.2793 | DTC Score=0.9304 | DTS Loss=13.3137 | DTS Score=0.8649
#
# Epoch 271 Train: DTC Loss=3.0652 | DTC Score=0.9461 | DTS Loss=11.1565 | DTS Score=0.8925
# Epoch 271 Val: DTC Loss=3.2187 | DTC Score=0.9388 | DTS Loss=12.9302 | DTS Score=0.8767
#
# Epoch 272 Train: DTC Loss=3.1351 | DTC Score=0.9463 | DTS Loss=11.3059 | DTS Score=0.8973
# Epoch 272 Val: DTC Loss=3.2409 | DTC Score=0.9363 | DTS Loss=12.9550 | DTS Score=0.8512
#
# Epoch 273 Train: DTC Loss=3.1361 | DTC Score=0.9443 | DTS Loss=11.1471 | DTS Score=0.8912
# Epoch 273 Val: DTC Loss=3.2850 | DTC Score=0.9412 | DTS Loss=12.8949 | DTS Score=0.8645
#
# Epoch 274 Train: DTC Loss=3.3093 | DTC Score=0.9405 | DTS Loss=11.1699 | DTS Score=0.9063
# Epoch 274 Val: DTC Loss=3.2282 | DTC Score=0.9407 | DTS Loss=12.8455 | DTS Score=0.8621
#
# Epoch 275 Train: DTC Loss=3.1963 | DTC Score=0.9415 | DTS Loss=11.2138 | DTS Score=0.8948
# Epoch 275 Val: DTC Loss=3.1764 | DTC Score=0.9393 | DTS Loss=12.8478 | DTS Score=0.8724
#
# Epoch 276 Train: DTC Loss=3.2014 | DTC Score=0.9444 | DTS Loss=11.2804 | DTS Score=0.8884
# Epoch 276 Val: DTC Loss=3.3244 | DTC Score=0.9321 | DTS Loss=13.0202 | DTS Score=0.8611
#
# Epoch 277 Train: DTC Loss=3.1342 | DTC Score=0.9399 | DTS Loss=11.2484 | DTS Score=0.8974
# Epoch 277 Val: DTC Loss=3.2898 | DTC Score=0.9373 | DTS Loss=12.7974 | DTS Score=0.8570
#
# Epoch 278 Train: DTC Loss=3.0795 | DTC Score=0.9488 | DTS Loss=11.0674 | DTS Score=0.9013
# Epoch 278 Val: DTC Loss=3.3552 | DTC Score=0.9327 | DTS Loss=13.2512 | DTS Score=0.8711
#
# Epoch 279 Train: DTC Loss=3.1601 | DTC Score=0.9420 | DTS Loss=11.1062 | DTS Score=0.9012
# Epoch 279 Val: DTC Loss=3.2191 | DTC Score=0.9379 | DTS Loss=13.0766 | DTS Score=0.8603
#
# Epoch 280 Train: DTC Loss=3.1347 | DTC Score=0.9432 | DTS Loss=11.3886 | DTS Score=0.8924
# Epoch 280 Val: DTC Loss=3.2627 | DTC Score=0.9363 | DTS Loss=13.3097 | DTS Score=0.8606
#
# Epoch 281 Train: DTC Loss=3.2552 | DTC Score=0.9380 | DTS Loss=11.1525 | DTS Score=0.8890
# Epoch 281 Val: DTC Loss=3.2584 | DTC Score=0.9377 | DTS Loss=12.9868 | DTS Score=0.8533
#
# Epoch 282 Train: DTC Loss=3.1122 | DTC Score=0.9473 | DTS Loss=10.9811 | DTS Score=0.9044
# Epoch 282 Val: DTC Loss=3.4895 | DTC Score=0.9248 | DTS Loss=13.0324 | DTS Score=0.8558
#
# Epoch 283 Train: DTC Loss=3.0956 | DTC Score=0.9439 | DTS Loss=11.2232 | DTS Score=0.8932
# Epoch 283 Val: DTC Loss=3.1663 | DTC Score=0.9406 | DTS Loss=13.1045 | DTS Score=0.8502
#
# Epoch 284 Train: DTC Loss=3.0385 | DTC Score=0.9464 | DTS Loss=10.9536 | DTS Score=0.9062
# Epoch 284 Val: DTC Loss=3.2965 | DTC Score=0.9345 | DTS Loss=13.1284 | DTS Score=0.8579
#
# Epoch 285 Train: DTC Loss=3.0911 | DTC Score=0.9457 | DTS Loss=11.2058 | DTS Score=0.8921
# Epoch 285 Val: DTC Loss=3.2042 | DTC Score=0.9415 | DTS Loss=12.8376 | DTS Score=0.8737
#
# Epoch 286 Train: DTC Loss=3.1067 | DTC Score=0.9447 | DTS Loss=11.0100 | DTS Score=0.8995
# Epoch 286 Val: DTC Loss=3.2617 | DTC Score=0.9331 | DTS Loss=12.7600 | DTS Score=0.8640
#
# Epoch 287 Train: DTC Loss=3.1949 | DTC Score=0.9420 | DTS Loss=11.1303 | DTS Score=0.8947
# Epoch 287 Val: DTC Loss=3.1675 | DTC Score=0.9424 | DTS Loss=12.8324 | DTS Score=0.8623
#
# Epoch 288 Train: DTC Loss=3.1665 | DTC Score=0.9416 | DTS Loss=11.1620 | DTS Score=0.8949
# Epoch 288 Val: DTC Loss=3.2091 | DTC Score=0.9381 | DTS Loss=13.1803 | DTS Score=0.8616
#
# Epoch 289 Train: DTC Loss=3.1729 | DTC Score=0.9416 | DTS Loss=11.1605 | DTS Score=0.8988
# Epoch 289 Val: DTC Loss=3.3203 | DTC Score=0.9336 | DTS Loss=13.0726 | DTS Score=0.8543
#
# Epoch 290 Train: DTC Loss=3.1678 | DTC Score=0.9411 | DTS Loss=11.0931 | DTS Score=0.9016
# Epoch 290 Val: DTC Loss=3.2663 | DTC Score=0.9356 | DTS Loss=12.8780 | DTS Score=0.8342
#
# Epoch 291 Train: DTC Loss=3.0901 | DTC Score=0.9459 | DTS Loss=11.1576 | DTS Score=0.8960
# Epoch 291 Val: DTC Loss=3.2528 | DTC Score=0.9425 | DTS Loss=12.6957 | DTS Score=0.8681
#
# Epoch 292 Train: DTC Loss=3.1318 | DTC Score=0.9460 | DTS Loss=11.1047 | DTS Score=0.9027
# Epoch 292 Val: DTC Loss=3.3305 | DTC Score=0.9298 | DTS Loss=13.2744 | DTS Score=0.8686
#
# Epoch 293 Train: DTC Loss=3.2991 | DTC Score=0.9376 | DTS Loss=11.3283 | DTS Score=0.8921
# Epoch 293 Val: DTC Loss=3.5266 | DTC Score=0.9297 | DTS Loss=13.2783 | DTS Score=0.8621
#
# Epoch 294 Train: DTC Loss=3.1925 | DTC Score=0.9417 | DTS Loss=11.3058 | DTS Score=0.8931
# Epoch 294 Val: DTC Loss=3.2666 | DTC Score=0.9399 | DTS Loss=12.7490 | DTS Score=0.8673
#
# Epoch 295 Train: DTC Loss=3.1608 | DTC Score=0.9431 | DTS Loss=11.2560 | DTS Score=0.8998
# Epoch 295 Val: DTC Loss=3.2105 | DTC Score=0.9415 | DTS Loss=12.8032 | DTS Score=0.8642
#
# Epoch 296 Train: DTC Loss=3.0886 | DTC Score=0.9442 | DTS Loss=10.9856 | DTS Score=0.8997
# Epoch 296 Val: DTC Loss=3.1981 | DTC Score=0.9397 | DTS Loss=12.9194 | DTS Score=0.8634
#
# Epoch 297 Train: DTC Loss=3.0989 | DTC Score=0.9427 | DTS Loss=10.9760 | DTS Score=0.9000
# Epoch 297 Val: DTC Loss=3.1785 | DTC Score=0.9422 | DTS Loss=13.0806 | DTS Score=0.8513
#
# Epoch 298 Train: DTC Loss=3.0713 | DTC Score=0.9492 | DTS Loss=10.8891 | DTS Score=0.9006
# Epoch 298 Val: DTC Loss=3.2736 | DTC Score=0.9398 | DTS Loss=12.7588 | DTS Score=0.8689
#
# Epoch 299 Train: DTC Loss=3.2550 | DTC Score=0.9381 | DTS Loss=11.1609 | DTS Score=0.8900
# Epoch 299 Val: DTC Loss=3.5584 | DTC Score=0.9264 | DTS Loss=13.0523 | DTS Score=0.8509
#
# Epoch 300 Train: DTC Loss=3.2315 | DTC Score=0.9404 | DTS Loss=11.2493 | DTS Score=0.8953
# Epoch 300 Val: DTC Loss=3.2360 | DTC Score=0.9398 | DTS Loss=12.9432 | DTS Score=0.8640

# %%
performance2(
        train_dtc_loss[1:], train_dtc_score[1:], train_dts_score[1:],
        train_dts_loss[1:], val_dtc_score[1:], val_dtc_loss[1:],
        val_dts_score[1:], val_dts_loss[1:]
        )

# %% [markdown]
# # Step 8: Inference

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# model = Log1DNetv3().to(device)
model.load_state_dict(torch.load('/content/best_model.pt'))

def predict_logs(x, y, original_df):

    inputs = torch.from_numpy(x.values).to(device).float()
    outputs = torch.from_numpy(y.values).to(device).float()

    dtcs = []; dtss = []
    model.eval()
    for i in range(inputs.shape[0]):
        with torch.inference_mode():
            pred = model(inputs[i].unsqueeze(0).repeat(256, 1, 1))
            dtc = pred[0][0]; dts = pred[0][1]
            dtcs.append(dtc.cpu().numpy()); dtss.append(dts.cpu().numpy())

    df = original_df.copy()
    df['Predicted DTC'] = np.array(dtcs).astype(float)
    df['Predicted DTS'] = np.array(dtss).astype(float)

    return df

# %%
#blind well 2

well2_new = predict_logs(test_well2_x, test_well2_y, well2)

metrics(pred=well2_new['Predicted DTC'], gt=well2_new['DTC'], name='DTC')
metrics(pred=well2_new['Predicted DTS'], gt=well2_new['DTS'], name='DTS')

make_log_plot(well2_new, 'GR', 'RT', 'RHOB','NPHI',  'DTC',
              'Predicted DTC', 'DTS', 'Predicted DTS', '15/9-F-11T2')
# Out:
# The R2 score for Well DTC: 0.9268148879388449
# The RMSE for Well DTC: 3.610908836970475
# --------------------------------------------------
# The R2 score for Well DTS: 0.7779579140991064
# The RMSE for Well DTS: 16.23010058984502
# --------------------------------------------------

# %%
# well 5
well5_new = predict_logs(test_well5_x, test_well5_y, well5)
metrics(pred=well5_new['Predicted DTC'], gt=well5_new['DTC'], name='DTC')
metrics(pred=well5_new['Predicted DTS'], gt=well5_new['DTS'], name='DTS')

make_log_plot(well5_new, 'GR', 'RT', 'RHOB', 'NPHI',
              'DTC', 'Predicted DTC', 'DTS', 'Predicted DTS', '15/9-F-4')
# Out:
# The R2 score for Well DTC: 0.8406554046049298
# The RMSE for Well DTC: 4.274898987543812
# --------------------------------------------------
# The R2 score for Well DTS: 0.5355113763264591
# The RMSE for Well DTS: 16.471426253118395
# --------------------------------------------------

# %%
#well1
well1_new = predict_logs(train_well1_x, train_well1_y, well1)
metrics(pred=well1_new['Predicted DTC'], gt=well1_new['DTC'], name='DTC')
metrics(pred=well1_new['Predicted DTS'], gt=well1_new['DTS'], name='DTS')

make_log_plot(well1_new, 'GR', 'RT', 'RHOB',
              'NPHI', 'DTC', 'Predicted DTC', 'DTS', 'Predicted DTS', '15/9-F-11A')
# Out:
# The R2 score for Well DTC: 0.952179442704584
# The RMSE for Well DTC: 3.215202771892317
# --------------------------------------------------
# The R2 score for Well DTS: 0.9108259764290471
# The RMSE for Well DTS: 12.679910583661911
# --------------------------------------------------

# %%
#well3
well3_new = predict_logs(train_well3_x, train_well3_y, well3)
metrics(pred=well3_new['Predicted DTC'], gt=well3_new['DTC'], name='DTC')
metrics(pred=well3_new['Predicted DTS'], gt=well3_new['DTS'], name='DTS')

make_log_plot(well3_new, 'GR', 'RT', 'RHOB','NPHI',
              'DTC', 'Predicted DTC', 'DTS', 'Predicted DTS', '15/9-F-1A')
# Out:
# The R2 score for Well DTC: 0.9550690059266818
# The RMSE for Well DTC: 2.8178621407195563
# --------------------------------------------------
# The R2 score for Well DTS: 0.8773487824165522
# The RMSE for Well DTS: 10.14525467762417
# --------------------------------------------------

# %%
#well4
well4_new = predict_logs(train_well4_x, train_well4_y, well4)
metrics(pred=well4_new['Predicted DTC'], gt=well4_new['DTC'], name='DTC')
metrics(pred=well4_new['Predicted DTS'], gt=well4_new['DTS'], name='DTS')

make_log_plot(well4_new, 'GR', 'RT', 'RHOB', 'NPHI', 'DTC',
              'Predicted DTC', 'DTS', 'Predicted DTS', '15/9-F-1B')
# Out:
# The R2 score for Well DTC: 0.9077992687931347
# The RMSE for Well DTC: 2.4423372884017014
# --------------------------------------------------
# The R2 score for Well DTS: 0.8111597217996332
# The RMSE for Well DTS: 7.46622787857814
# --------------------------------------------------
